# %% [markdown]
# # Lexicon Acquisition
# ## Andrew McIsaac

# %% [markdown]
# ## Tags
#
# **ADJE**: Adjective
#
# **ADVB**: Adverb - can be types Cmp (Comparative), Dem (Demonstrative), Int (Interrogative), Pos (Possessive)
#
# **CIRC**: Circumposition
#
# **CONJ**: Coordinating Conjunction
#
# **DETR**: Determiner - has a gender (M,F,N,P) - and type (Art: Article, Dem: Demonstrative, Ind: Indefinite, Int: Interrogative, Prs: Personal, Rel: Relative)
#
# **INTJ**: Interjection
#
# **NOUN**: Noun - has a gender (M,F,N,P,S (for singular unknown)) - and optional type based on the forms the noun takes in the plural (Weak is for N-declension nouns)
#
# **NUMB**: Number
#
# **PART**: Particle
#
# **PINF**: Particle Infinitive ('zu')
#
# **POST**: Postposition
#
# **PREP**: Preposition
#
# **PRES**: Particle Response (e.g. 'ja', 'nein')
#
# **PRON**: Pronoun - has a (optional) person (1,2,3) and gender (M,F,N,P,S) - and optional type (Prs: Personal, Ref: Reflexive, plus as determiners)
#
# **PRPN**: Proper Noun - has a gender (M,F,N,P,S)
#
# **SCNJ**: Subordinating Conjunction
#
# **VAUX**: Auxiliary Verb - type is any of the three auxiliary verbs (haben, sein, werden)
#
# **VMIX**: Mixed Verb
#
# **VMOD**: Modal Verb - type is any of the six modal verbs
#
# **VSTR**: Strong Verb - has a type based on class (1-7) - see strong verbs section for more
#
# **VWEK**: Weak Verb

# %% [markdown]
# All items of the lexicon are included as WORD, TAG and are tab-separated, except for the tags VMIX, VSTR, and VWEK.
# These are grouped by their infinitive forms combined with the set of separable prefixes they can take followed by the tag which is again tab-separated.

# %%
import re
from collections import Counter
from collections import defaultdict

with open("de-tagged.txt", "r") as f:
    # make a list of [word, tags], ignoring empty lines
    de = [line.split("\t") for line in f.read().splitlines() if line.strip()]
len(de)
# Out:
# 712332

# %%
# create tuples of (word, tag)
de = [(line[0].lower(), line[1]) for line in de] # lower-case the words, but not the tags

# %%
# filter out punctuation, symbols, unknowns, and digits
de_filtered = list(filter(lambda l: ('PUNCT' not in l[1]) and ('SYM' not in l[1]) and (not re.search(r'^X\|', l[1])) and (not re.search(r'(\d+|[^\w\s]+)', l[0])), de))

len(de_filtered)
# Out:
# 593015

# %%
# remove duplicates and sort by count
de_counter = Counter(de_filtered)
de_sorted = de_counter.most_common()

len(de_sorted)
# Out:
# 101695

# %% [markdown]
# #### Closed-Class Words

# %%
lexicon = []
#  add conjunctions to lexicon 
lexicon += {(word, tag.split("|")[0]) for (word, tag), _ in list(filter(lambda c: re.match(r'CONJ', c[0][1]), de_sorted))}

# remove coordinating conjunctions from vocab list
de_sorted = list(filter(lambda c: not re.match(r'CONJ', c[0][1]), de_sorted))

# add subordinating conjunctions to lexicon
# lose some information (e.g. 'ums' is a contraction from 'um das', not picked up here)
lexicon += {(word, "SCNJ") for (word, tag), _ in list(filter(lambda c: re.match(r'SCONJ', c[0][1]), de_sorted))}

# remove subordinating conjunctions from vocab list
de_sorted = list(filter(lambda c: not re.match(r'SCONJ', c[0][1]), de_sorted))

# %%
# separable verb prefixes - save list for later verbs
# not words on their own (or are tagged appropriately when used with a different meaning)
# so don't add to lexicon
sep_verb_prefixes = {word for (word, tag), _ in list(filter(lambda c: re.search(r'PartType=Vbp', c[0][1]), de_sorted))}

# remove separable verb prefixes form vocab list
de_sorted = list(filter(lambda c: not re.search(r'PartType=Vbp', c[0][1]), de_sorted))

lexicon += {("zu", "PINF")}
de_sorted = list(filter(lambda c: not re.search(r'PartType=Inf', c[0][1]), de_sorted))

lexicon += {(word, "PRES") for (word, tag), _ in list(filter(lambda c: re.search(r'PartType=Res', c[0][1]), de_sorted))}
de_sorted = list(filter(lambda c: not re.search(r'PartType=Res', c[0][1]), de_sorted))

# %%
# add remaining particles to the lexicon
lexicon += {(word, "PART") for (word, tag), _ in list(filter(lambda c: re.match(r'PART', c[0][1]), de_sorted))}

# %%
# remove particles from vocab list 
de_sorted = list(filter(lambda c: not re.match(r'PART', c[0][1]), de_sorted))

# %%
def map_gender_number(tag):
    '''returns 'P' if plural, gender ('M', 'F', 'N') otherwise'''
    if "Number=Plur" in tag:
        return "P"
    elif "Gender=" in tag:
        return tag.split("Gender=")[1][0]
    # number and gender not specified
    return "S"

# %%
# add determiners to the lexicon
# articles
# from UD website: determiners inflect for gender and plurality
# four cases - nominative, accusative, dative, genitive - nominative case for three genders and plural
dets = list(filter(lambda c: re.search(r'DET.*Case=Nom\|Gender=.*PronType=.*', c[0][1]), de_sorted))
lexicon += {(word, "DETR|"+map_gender_number(tag)+"|"+tag.split("PronType=")[1][:3]) for (word, tag), _ in dets}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^DET', c[0][1]), de_sorted))

# %%
len(de_sorted)
# Out:
# 100750

# %%
def map_gender_number_person(word,tag):
    '''returns number/gender, person, and plurality'''
    string = ""
    string += tag.split("Person=")[1][0]
    if "Number=Plur" in tag:
        string += "P"
    else:
        string += tag.split("Gender=")[1][0] if "Gender" in tag and string[0] == "3" else "S"
    return string

# %%
# add pronouns to the lexicon
# inflect for cases - nom, acc, dat, gen
# singular (1, 2, 3 (plus genders)), plural (1, 2, 3)
# reflexive - only takes accusative or dative
reflexive = list(filter(lambda c: re.search(r'PRON\|Case=Acc.*Person.*Reflex=Yes', c[0][1]), de_sorted))
lexicon += {(word, "PRON|"+map_gender_number_person(word, tag)+"|Ref") for (word, tag), _ in reflexive}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^PRON.*Reflex=Yes', c[0][1]), de_sorted))

# %%
# personal
prons = list(filter(lambda c: re.search(r'PRON\|Case=Nom.*Person.*PronType=Prs', c[0][1]), de_sorted))
lexicon += {(word, "PRON|"+map_gender_number_person(word, tag)+"|"+tag.split("PronType=")[1][:3]) for (word, tag), _ in prons}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^PRON.*PronType=Prs', c[0][1]), de_sorted))

# %%
# relative
rels = list(filter(lambda c: re.search(r'PRON\|Case=Nom.*PronType=Rel', c[0][1]), de_sorted))
lexicon += {(word, "PRON|"+map_gender_number(tag)+"|Rel") for (word, tag), _ in rels}

# %%
# interrogative
interrogatives = list(filter(lambda c: re.search(r'PRON\|Case=Nom.*PronType=Int(?!.*Person)', c[0][1]), de_sorted))
lexicon += {(word, "PRON|"+map_gender_number(tag)+"|"+tag.split("PronType=")[1][:3]) for (word, tag), _ in interrogatives}

# %%
rest = list(filter(lambda c: re.search(r'PRON\|Case=Nom', c[0][1]), de_sorted))
lexicon += {(word, "PRON|"+map_gender_number(tag)+"|"+tag.split("PronType=")[1][:3]) for (word, tag), _ in rest}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^PRON', c[0][1]), de_sorted))

# %%
# add adpositions to the lexicon
# some prepositions are contractions of preposition + article
# filter out by ignoring items where case or prontype is specified
adps = list(filter(lambda c: re.search(r'ADP.*AdpType=(?!.*Case|.*PronType)', c[0][1]), de_sorted))
lexicon += {(word, tag.split("AdpType=")[1][:4].upper()) for (word, tag), _ in adps}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^ADP', c[0][1]), de_sorted))

# %%
# pronominal adverbs
adverbs = list(filter(lambda c: re.search(r'ADV.*PronType', c[0][1]), de_sorted))
lexicon += {(word, "ADVB|"+tag.split("PronType=")[1][:3]) for (word, tag), _ in adverbs}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^ADV.*PronType', c[0][1]), de_sorted))

# %%
# only cardinal numbers tagged as NUM
lexicon += {(word, "NUMB") for (word, tag), _ in list(filter(lambda c: re.search(r'NUM', c[0][1]), de_sorted))}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^NUM', c[0][1]), de_sorted))

# %%
# auxiliary verbs
# keep infinitives - types are the three infinitives
# since conjugations are very irregular
auxs = list(filter(lambda c: re.search(r'AUX.*VerbForm=Inf', c[0][1]), de_sorted))
lexicon += {(word, "VAUX|"+word.upper()) for (word, tag), count in auxs if count > 5} # ignore misclassifieds

# %%
de_sorted = list(filter(lambda c: not re.search(r'^AUX', c[0][1]), de_sorted))

# %%
# modal verbs - types are infinitives since conjugations are irregular and different
# look through first person plurals too since the conjugation is the same as the infinitive
modals = list(filter(lambda c: re.search(r'VerbForm=Inf\|VerbType=Mod', c[0][1]), de_sorted))
modals += list(filter(lambda c: re.search(r'VERB\|Mood=Ind\|Number=Plur\|Person=1\|Tense=Pres.*VerbType=Mod', c[0][1]), de_sorted))
lexicon += {(word, "VMOD|"+word.upper()) for (word, tag), count in modals if count > 1}

# %%
de_sorted = list(filter(lambda c: not re.search(r'VerbType=Mod', c[0][1]), de_sorted))

# %% [markdown]
# #### Open-Class Words

# %%
len(de_sorted)
# Out:
# 99223

# %%
{tag.split("|")[0] for (_, tag), _ in de_sorted}
# Out:
# {'ADJ', 'ADV', 'INTJ', 'NOUN', 'PROPN', 'VERB'}

# %%
# interjections
lexicon += {(word, tag.split("|")[0]) for (word, tag), _ in de_sorted if tag.split("|")[0] == "INTJ"}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^INTJ', c[0][1]), de_sorted))

# %%
# verbs - split into mixed, strong and weak verbs
# in the format ((verb, {prefixes}), tag), so that a verb is listed with its known separable verb prefixes
# e.g. (('denken', {'aus', 'hinterher', 'mit', 'nach', 'zurück', 'über'}), 'VMIX')

# enumerate mixed verbs - form past tense with vowel shift and hard consonant sound
re_infinitive = re.compile(r'^VERB.*VerbForm=Inf')
# 1st/3rd person plural takes same form as infinitive, so make sure to include these
re_plurals = re.compile(r'^VERB\|Mood=Ind\|Number=Plur\|Person=(1|3)\|Tense=Pres.*VerbForm=Fin')

mixed = ["brennen", "bringen", "denken", "kennen", "nennen", "rennen", "senden", "wenden", "wissen"]
mixed_inf = {word for (word, tag), _ in list(filter(lambda c: re.search(re_infinitive, c[0][1]), de_sorted))}
mixed_inf = mixed_inf.union({word for (word, tag), _ in list(filter(lambda c: re.search(re_plurals, c[0][1]), de_sorted))}).intersection(set(mixed))

# %%
def sep_verbs(prefixes, verbs, re_search):
    # returns list of tuples of verbs and their set of seen separable prefixes
    separable_verbs = []
    de_filtered = list(filter(lambda c: re.search(re_search, c[0][1]), de_sorted))
    for verb in verbs:
        valid_prefixes = []
        for prefix in prefixes:
            if prefix+verb in [word for (word, _), _ in de_filtered]:
                valid_prefixes.append(prefix)
        separable_verbs.append({verb: valid_prefixes})
    return separable_verbs

# %%
def get_verb_prefixes(verbs):
    '''
    verbs is a list of verbs in their infinitive form
    returns a list of verbs and their separable prefixes
    '''
    # check for separable verb prefixes in both infinitive form and plural form of the verbs
    sep_infs = sep_verbs(sep_verb_prefixes, verbs, re_infinitive)
    sep_plurals = sep_verbs(sep_verb_prefixes, verbs, re_plurals)
    
    sep = sep_plurals + sep_infs
    
    # merge where the infinitive of the verb has been picked up twice
    d = defaultdict(set)
    for myd in sep:
        for k, v in myd.items():
            d[k].update(v)
    
    return d.items()

# %%
lexicon += [((verb, prefixes), "VMIX") for verb, prefixes in get_verb_prefixes(mixed_inf)]

# %%
de_sorted = list(filter(lambda c: not (re.search(r'^VERB.*VerbForm=Inf', c[0][1]) and c[0][0] in mixed), de_sorted))

# %%
# enumerate strong verbs from list of strong verbs
# 7 classes, as in https://en.wikipedia.org/wiki/Germanic_strong_verb#German
# based on first vowel cluster
# Class 1: ablaut vowel followed by -y- in PIE, "ei, ie, ie" or "ei, i, i" (present, preterite, participle)
# Class 2: ablaut vowel followed by -w- in PIE, "ie, o, o"
# Class 3a: ablaut vowel followed by consonant cluster in PIE, "i, a, u"
# Class 3b: ablaut vowel followed by consonant cluster in PIE, "e, a, o"
# Class 4: ablaut vowel followed by sonorant (m,n,l,r) in PIE, "e, a, o" - identical to 3b in modern German (so classify all as 4 for simplicity)
# Class 5: ablaut vowel followed by non-sonorant consonant in PIE, "e, a, e"
# Class 6: "a, u, a"
# Class 7: preterite formed with "ie", participle is ge+infinitive
with open("strong.txt", "r") as f:
    strong = f.read().splitlines()

strong_inf = {word for (word, tag), _ in list(filter(lambda c: re.search(r'^VERB.*VerbForm=Inf', c[0][1]), de_sorted))}.intersection(set(strong))
#strong_infs = {(word, tag) for (word, tag), _ in de_sorted if word in strong_inf}
#classes = {"1": "ei", "2": "ie", "3a": "i", "4": "e", "5": "e", 
#           "6": "a", "7b": "au", "7c": "a", "7d": "a", "7e": "o"}
classes = {"ei": ["1"], "ie": ["2"], "i": ["3"], "e": ["4", "5"],
          "a": ["6", "7"], "au": ["7"], "o": ["7"], "ü": ["2"], "u": ["7"]}

# %%
# class 1
insep_prefixes = ["be", "emp", "ent", "er", "fern", "miss", "unter", "ver", "voll", "zer"]
vowels = re.compile(r'aeiouäöü')
# we want the ablaut vowels, which means removing inseparable prefixes from infinitives so that first vowel cluster is the ablaut vowel cluster
# "ge" is a special case - can either be insep prefix or part of the stem - filter out separable
insep_infins = set(filter(lambda word: list(filter(word.startswith, insep_prefixes)), strong_inf))
ge_infins = set(filter(lambda word: word.startswith("ge"), strong_inf))
separable_ges = {'gefallen', 'gelingen', 'genießen', 'geraten', 'geschehen', 'gewinnen'}
strong_inf = strong_inf - insep_infins - separable_ges - {"heißen"}

# %%
def remove_prefix(text, prefixes):
    # split based on specific prefix
    pref = list(filter(text.startswith, prefixes))[0]
    return pref, text[len(pref):]

insep_stems = [remove_prefix(word, insep_prefixes) for word in insep_infins]

# %%
# find first vowel cluster
vowel_clusters = [(word, re.findall(r"\b\w*?([aeiouäöü]{1,2})", word)[0]) for word in strong_inf]
vowel_clusters += [(word[0]+word[1], re.findall(r"\b\w*?([aeiouäöü]{1,2})", word[1])[0]) for word in insep_stems]

# %%
verb_classes = [(word[0], classes[word[1]] if word[1] in classes.keys() else []) for word in vowel_clusters]

# %%
# heißen is a special case for 7, so add it separately
sep_verbs(sep_verb_prefixes, ['heißen'], re_infinitive)
# Out:
# [{'heißen': []}]

# %%
lexicon += [(("heißen", set()), "VSTR|7")]

# %%
verb_classes_verbs = [word for (word, classes) in verb_classes]

# add strong verbs with only one possible class to their classes 
# a few anomalies missed - e.g. kommen misclassified to be in 7 when should be in 4
lexicon += [((verb, prefixes), "VSTR|"+classes[0]) for (verb, prefixes), (word, classes) in 
     zip(get_verb_prefixes(verb_classes_verbs), verb_classes) if len(classes) ==1]

# %%
verb_classes = [(word, classes) for (word, classes) in verb_classes if len(classes) != 1]

# %%
four_five = [(word, classes) for (word, classes) in verb_classes if classes == ['4','5']]
six_seven = [(word, classes) for (word, classes) in verb_classes if classes == ['6','7']]

# %%
# distinguish between four and five
# have to look for past participle vowel changes 
# four: e-a-o
# five: e-a-e

consonants = [word[0].split("e") for word in four_five]

regex_consonants = []
for word in consonants:
    regex = "^ge"
    for part in word[:-1]:
        regex += part
        regex += ".*"
    regex += "en"
    regex_consonants.append(regex)
regex_consonants

past_parts = list(filter(lambda c: re.search(r'^VERB.*VerbForm=Part', c[0][1]), de_sorted))

past_part_verbs = [word for (word, tag), _ in past_parts]
past_part_verbs

for pattern in regex_consonants:
    patt = re.compile(pattern)
    l = list(filter(lambda c: re.search(patt, c), past_part_verbs))
    if l:
        print(pattern, l)
# Out:
# ^getr.*t.*en ['getreten']
# ^gest.*hl.*en ['gestohlen']
# ^ges.*h.*en ['gesehen', 'geschaffen', 'gesprochen', 'geschlossen', 'geschrieben', 'gestrichen', 'geschlagen', 'geschehen', 'geschoben', 'geschossen', 'gestohlen', 'geschieden', 'geschenkt', 'geschlafen', 'gestrichenn', 'geschrien', 'geschliffen', 'geschlichen', 'geschwiegen', 'gescholten', 'geschwungen', 'geschnitten', 'geschworen', 'geschwollen']
# ^gest.*h.*en ['gestrichen', 'gestohlen', 'gestrichenn']
# ^geh.*lf.*en ['geholfen']
# ^getr.*ff.*en ['getroffen']
# ^geg.*h.*en ['gegenübergesehen']
# ^gebr.*ch.*en ['gebrochen']
# ^geg.*lt.*en ['gegolten']
# ^geh.*b.*en ['gehoben']
# ^ge.*ss.*en ['geschlossen', 'gemessen', 'gelassen', 'geflossen', 'geschossen', 'gesessen', 'gerissen', 'genossen', 'gegossen']
# ^gel.*s.*en ['gelesen', 'gelassen']
# ^gew.*rf.*en ['geworfen']
# ^gem.*ss.*en ['gemessen']
# ^geg.*b.*en ['gegeben', 'gegenübergesehen', 'gegraben']
# ^gespr.*ch.*en ['gesprochen']
# ^gew.*rb.*en ['geworben']
# ^gest.*rb.*en ['gestorben']

# %%
# manual addition to lexicon
four = {'treffen', 'werben', 'nehmen', 'helfen', 'heben', 'brechen', 'sterben', 'stehlen', 'werfen', 'sprechen', 'unterbrechen', 'verbergen', 'unternehmen', 'bewegen', 'empfehlen', 'gelten'}
five = {verb[0] for verb in four_five} - four

lexicon += [((verb, prefixes), "VSTR|4") for verb, prefixes in get_verb_prefixes(four)]
lexicon += [((verb, prefixes), "VSTR|5") for verb, prefixes in get_verb_prefixes(five)]

# %%
class_seven_preterites = list(filter(lambda c: re.search(r'^VERB.*Mood=Ind\|Number=Sing.*Tense=Past.*VerbForm=Fin', c[0][1]) and "ie" in c[0][0], de_sorted))

# %%
# distinguish between classes six and seven
# can determine manually depending on preterites
# i.e. if preterite form of infinitive appears in candidates from regex pattern,
# it is class seven, else class six
consonants = [word[0].split("a") for word in six_seven]

regex_consonants = []
for word in consonants:
    regex = "^"
    for part in word[:-1]:
        regex += part
        regex += ".*"
    regex_consonants.append(regex)

class_seven_preterites = list(filter(lambda c: re.search(r'^VERB.*Mood=Ind\|Number=Sing.*Tense=Past.*VerbForm=Fin', c[0][1]) and "ie" in c[0][0], de_sorted))

class_seven_verbs = [word for (word, tag), _ in class_seven_preterites]

for i, pattern in enumerate(regex_consonants):
    patt = re.compile(pattern)
    l = list(filter(lambda c: re.search(patt, c), class_seven_verbs))
    if l:
        print(six_seven[i][0], l)
# Out:
# waschen ['wies', 'wiederholte', 'wies']
# wachsen ['wies', 'wiederholte', 'wies']
# halten ['hieß', 'hielt', 'hinterließ', 'halbierte', 'herunterkopierte', 'hervorrief', 'havarierte', 'hinwies']
# schaffen ['schien', 'schrieb', 'schwieg', 'schrie', 'schrie', 'schwieg']
# laden ['ließ', 'lief', 'lieferte', 'liess', 'liebte', 'liebäugelte', 'liebte', 'logierte', 'lancierte', 'lavierte', 'legitimierte']
# fangen ['fiel', 'feierte', 'formulierte', 'funktionierte', 'fungierte', 'fabulierte', 'firmierte', 'finanzierte']
# fallen ['fiel', 'feierte', 'formulierte', 'funktionierte', 'fungierte', 'fabulierte', 'firmierte', 'finanzierte']
# lassen ['ließ', 'lief', 'lieferte', 'liess', 'liebte', 'liebäugelte', 'liebte', 'logierte', 'lancierte', 'lavierte', 'legitimierte']
# graben ['grassierte']
# blasen ['blieb', 'blieb']
# fahren ['fiel', 'feierte', 'formulierte', 'funktionierte', 'fungierte', 'fabulierte', 'firmierte', 'finanzierte']
# tragen ['trieb', 'transportierte', 'traktierte', 'triumphierte']
# raten ['rief', 'reagierte', 'riet', 'riskierte', 'registrierte', 'reflektierte', 'reduzierte', 'revolutionierte', 'rangierte', 'rasierte', 'repräsentierte', 'rekrutierte', 'realisierte', 'retuschierte', 'regierte', 'relativierte', 'redigierte', 'reaktivierte']
# verlassen ['verließ', 'verlief', 'verlieh', 'verliebte', 'verlief']

# %%
# manual addition to lexicon
seven = {'blasen', 'halten', 'lassen', 'raten', 'fallen', 'verlassen'}
six = {verb[0] for verb in six_seven} - seven

lexicon += [((verb, prefixes), "VSTR|6") for verb, prefixes in get_verb_prefixes(six)]
lexicon += [((verb, prefixes), "VSTR|7") for verb, prefixes in get_verb_prefixes(seven)]

# %%
# remove strong verb infinitives from corpus
de_sorted = list(filter(lambda c: not (c[0][0] in strong_inf and re.search('VERB\|VerbForm=Inf', c[0][1])), de_sorted))

# %%
# weak verbs
weak_verb_infs = [word for (word, tag), _ in list(filter(lambda c: re.search(r'^VERB.*VerbForm=Inf', c[0][1]), de_sorted))]

# %%
weak_verb_plurals = [word for (word, tag), _ in list(filter(lambda c: re.search(re_plurals, c[0][1]), de_sorted))]

# %%
weak_verbs = weak_verb_infs + weak_verb_plurals

# %%
lexicon += [((verb, prefixes), "VWEK") for verb, prefixes in get_verb_prefixes(weak_verbs)]

# %%
de_sorted = list(filter(lambda c: not re.search(r'^VERB', c[0][1]), de_sorted))

# %%
# adverbs
# some adverbs inflect for degree - positive and comparative
advs_degree = list(filter(lambda c: re.search(r'^ADV\|Degree=', c[0][1]), de_sorted))
lexicon += {(word, "ADVB|"+tag.split("Degree=")[1].upper()) for (word, tag), _ in advs_degree}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^ADV\|Degree=', c[0][1]), de_sorted))

# %%
# most adverbs do not have any inflection, so just enumerate the rest
adverbs = list(filter(lambda c: re.search(r'^ADV', c[0][1]), de_sorted))
lexicon += {(word, "ADVB") for (word, tag), _ in adverbs}

# %%
de_sorted = list(filter(lambda c: not re.search(r'^ADV', c[0][1]), de_sorted))

# %%
# adjectives
# adjectives are either predicative (short) or attributive (long)
# inflection occurs when attributive - when they appear before a noun
# e.g. "Der Hund ist groß und braun" vs "Der große und braune Hund"
# inflection cases depend on whether there is a definite article, indefinite article, or no article before the noun
# requires syntactic rules to determine, so base form (short) is listed and inflections can be determined based on syntax

# degree is either positive (base), comparative or superlative
# comparative adds -er and sometimes adds an umlaut to the base form and further inflects as above
# superlative is am (base)-sten with a few exceptions as the base form, but is -st before the noun
# sometimes slightly different (e.g. hoch -> hoher), but these are rare cases


adjs = list(filter(lambda c: re.search(r'^ADJ.*Degree=Pos.*Variant=Short', c[0][1]), de_sorted))
lexicon += {(word, "ADJE") for (word, tag), _ in adjs}

# %%
list(filter(lambda c: re.search(r'^ADJ.*Degree=[^(Pos|Sup)]', c[0][1]), de_sorted))
# Out:
# [(('später', 'ADJ|Degree=Cmp|Variant=Short'), 121),
#  (('besser', 'ADJ|Degree=Cmp|Variant=Short'), 94),
#  (('stärker', 'ADJ|Degree=Cmp|Variant=Short'), 83),
#  (('frühere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 59),
#  (('länger', 'ADJ|Degree=Cmp|Variant=Short'), 55),
#  (('früher', 'ADJ|Degree=Cmp|Variant=Short'), 46),
#  (('höher', 'ADJ|Degree=Cmp|Variant=Short'), 44),
#  (('weitere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 42),
#  (('weiterer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 36),
#  (('weitere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 35),
#  (('schneller', 'ADJ|Degree=Cmp|Variant=Short'), 33),
#  (('größer', 'ADJ|Degree=Cmp|Variant=Short'), 31),
#  (('weitere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 31),
#  (('früheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'), 26),
#  (('weitere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 25),
#  (('weitere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 25),
#  (('tiefer', 'ADJ|Degree=Cmp|Variant=Short'), 21),
#  (('teurer', 'ADJ|Degree=Cmp|Variant=Short'), 20),
#  (('früheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 19),
#  (('weiteren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 19),
#  (('näher', 'ADJ|Degree=Cmp|Variant=Short'), 19),
#  (('weiteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 18),
#  (('häufiger', 'ADJ|Degree=Cmp|Variant=Short'), 18),
#  (('leichter', 'ADJ|Degree=Cmp|Variant=Short'), 18),
#  (('wichtiger', 'ADJ|Degree=Cmp|Variant=Short'), 17),
#  (('höhere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 17),
#  (('billiger', 'ADJ|Degree=Cmp|Variant=Short'), 15),
#  (('enger', 'ADJ|Degree=Cmp|Variant=Short'), 14),
#  (('weitere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 14),
#  (('größere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 14),
#  (('weiter', 'ADJ|Degree=Cmp|Variant=Short'), 14),
#  (('schlechter', 'ADJ|Degree=Cmp|Variant=Short'), 13),
#  (('weiteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 13),
#  (('früheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 13),
#  (('weiteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 12),
#  (('bessere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 12),
#  (('geringer', 'ADJ|Degree=Cmp|Variant=Short'), 11),
#  (('schlimmer', 'ADJ|Degree=Cmp|Variant=Short'), 11),
#  (('weitere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 11),
#  (('früheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 11),
#  (('höhere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 11),
#  (('weiteres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 11),
#  (('niedriger', 'ADJ|Degree=Cmp|Variant=Short'), 11),
#  (('früheren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 10),
#  (('weiteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 10),
#  (('früheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 10),
#  (('weiteres', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 10),
#  (('deutlicher', 'ADJ|Degree=Cmp|Variant=Short'), 10),
#  (('lieber', 'ADJ|Degree=Cmp|Variant=Short'), 9),
#  (('größere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 9),
#  (('früherer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 9),
#  (('härter', 'ADJ|Degree=Cmp|Variant=Short'), 9),
#  (('schärfer', 'ADJ|Degree=Cmp|Variant=Short'), 9),
#  (('schwächer', 'ADJ|Degree=Cmp|Variant=Short'), 9),
#  (('weitere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 9),
#  (('stärkere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 9),
#  (('höheren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 8),
#  (('sicherer', 'ADJ|Degree=Cmp|Variant=Short'), 8),
#  (('längere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 8),
#  (('früheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 8),
#  (('bessere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 8),
#  (('genauer', 'ADJ|Degree=Cmp|Variant=Short'), 7),
#  (('kleiner', 'ADJ|Degree=Cmp|Variant=Short'), 7),
#  (('weitere', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 7),
#  (('höhere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 7),
#  (('weitere', 'ADJ|Case=Nom|Degree=Cmp|Number=Plur'), 6),
#  (('langsamer', 'ADJ|Degree=Cmp|Variant=Short'), 6),
#  (('früheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 6),
#  (('kürzer', 'ADJ|Degree=Cmp|Variant=Short'), 6),
#  (('besseren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 6),
#  (('flexibler', 'ADJ|Degree=Cmp|Variant=Short'), 6),
#  (('größeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 6),
#  (('schwieriger', 'ADJ|Degree=Cmp|Variant=Short'), 6),
#  (('lauter', 'ADJ|Degree=Cmp|Variant=Short'), 6),
#  (('längerer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 6),
#  (('ältere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 6),
#  (('einfacher', 'ADJ|Degree=Cmp|Variant=Short'), 6),
#  (('ältere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 6),
#  (('intensiver', 'ADJ|Degree=Cmp|Variant=Short'), 6),
#  (('weiterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 6),
#  (('engere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 6),
#  (('frühere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 5),
#  (('rascher', 'ADJ|Degree=Cmp|Variant=Short'), 5),
#  (('früheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 5),
#  (('höheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 5),
#  (('ärmer', 'ADJ|Degree=Cmp|Variant=Short'), 5),
#  (('höhere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 5),
#  (('weiteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 5),
#  (('ältere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 5),
#  (('höheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 5),
#  (('weniger', 'ADJ|Degree=Cmp|Variant=Short'), 5),
#  (('kleinere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 5),
#  (('größeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 4),
#  (('größere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 4),
#  (('frühere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 4),
#  (('größeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 4),
#  (('kleinere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 4),
#  (('nähere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 4),
#  (('effektiver', 'ADJ|Degree=Cmp|Variant=Short'), 4),
#  (('günstiger', 'ADJ|Degree=Cmp|Variant=Short'), 4),
#  (('längerem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 4),
#  (('älter', 'ADJ|Degree=Cmp|Variant=Short'), 4),
#  (('früheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 4),
#  (('jünger', 'ADJ|Degree=Cmp|Variant=Short'), 4),
#  (('höhere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 4),
#  (('reicher', 'ADJ|Degree=Cmp|Variant=Short'), 4),
#  (('höheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 4),
#  (('sinnvoller', 'ADJ|Degree=Cmp|Variant=Short'), 4),
#  (('jüngeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 4),
#  (('kleinere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 4),
#  (('kleineren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('größeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('geringere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 3),
#  (('schlechtere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('weiterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Plur'), 3),
#  (('weiteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 3),
#  (('verträglicher', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('weiteren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('weiteren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 3),
#  (('höheren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('höhere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('kleineren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('effektivere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('billigeres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 3),
#  (('seltener', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('höherer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('ältere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('weiterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('kleineren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 3),
#  (('längerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('längere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('kürzere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('späteren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('kleineren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('älterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 3),
#  (('geringeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('niedrigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('älteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('bessere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('kleinerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Plur'), 3),
#  (('bessere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('höheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('wahrscheinlicher', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('größerer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('größeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 3),
#  (('breitere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('älterer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('weiteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('attraktiver', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('längeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('freier', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('kleinere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('stärkere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('stärkeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 3),
#  (('schärfere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('knapper', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('längere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('späteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 3),
#  (('spätere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('erfolgreicher', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('frühere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 3),
#  (('härtere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 3),
#  (('schöner', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('schlanker', 'ADJ|Degree=Cmp|Variant=Short'), 3),
#  (('älteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 3),
#  (('besserer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('bedeutender', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('bessere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('billigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('frühere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('höhere', 'ADJ|Case=Nom|Degree=Cmp|Number=Plur'), 2),
#  (('früheres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('größere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('längerem', 'ADJ|Case=Dat|Degree=Cmp|Number=Sing'), 2),
#  (('direkter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('geringere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('wohler', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('höheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('früherer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('früheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('höheren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('straffer', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('gelassener', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('deutlich', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('längere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('kleineres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('umweltfreundlicher', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('kleineren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('vielfältiger', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('bequemere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('weiteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('längeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('ältere', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 2),
#  (('leiser', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('geringere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('jüngeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('gewichtiger', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('ungünstiger', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('richtiger', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('letzteren', 'ADJ|Case=Dat|Degree=Cmp|Number=Plur'), 2),
#  (('älteres', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('geringeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('zurückhaltender', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('höhere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('breiteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('breiter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('schwerer', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('größeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('kleineren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('größere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 2),
#  (('jüngere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('höherer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('größeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('früheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Plur'), 2),
#  (('nähere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('milder', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('öfter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('älteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('frühere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('rosiger', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('größerer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('preiswerteren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 2),
#  (('allgemeiner', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('ältere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('früherer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('berühmter', 'ADJ|Degree=Cmp'), 2),
#  (('komplizierter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('jüngeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('besseren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 2),
#  (('größeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('bunter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('höherer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('höherem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('konkreter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('interessanter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('dicker', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('niedrigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('schwereren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('differenzierter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('späteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('kleinere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 2),
#  (('größere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 2),
#  (('kürzeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('kürzere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('größere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('drängender', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('freundlicher', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('nüchterner', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('besseren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('älteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 2),
#  (('längeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 2),
#  (('langsameren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('frühere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('besseren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('kostengünstiger', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('flauere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 2),
#  (('gerechter', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('besseren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('klüger', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('höheres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 2),
#  (('kräftiger', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('besseren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('frühere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('besserer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('größere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 2),
#  (('sachlicher', 'ADJ|Degree=Cmp|Variant=Short'), 2),
#  (('niedrigeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'), 2),
#  (('krummeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('zarter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('lichter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('effektivere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('subtileren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('früher', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 1),
#  (('niedrigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('zäher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('zügiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('früheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('älterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('kostengünstigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('billigere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('kostengünstigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('liberaleres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('chaotischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('bedrohlicheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('schwierigeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('stärkere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('unwürdigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('längeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('niedrigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('treffender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('schärferen', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('patientennäher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kostengünstigeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('billigerer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('positiver', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kleinere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('aktueller', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('rauhere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('präzisere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('bessere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('leistungsfähigere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('stärkere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('leichteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('dürftiger', 'ADJ|Degree=Cmp'), 1),
#  (('näheren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('früheren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('auswegloser', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('spürbarer', 'ADJ|Degree=Cmp'), 1),
#  (('gerechtere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('verständlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('größerem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('jüngere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('strengere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('sozialeres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('verzweifelter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('effizientere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('niedrigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('drastischer', 'ADJ|Degree=Cmp'), 1),
#  (('stärkere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('militantere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('fein', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('totalitärer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('geigneter', 'ADJ|Degree=Cmp'), 1),
#  (('realitätsferner', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('offener', 'ADJ|Degree=Cmp'), 1),
#  (('niedrigerem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('kürzere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('kleinerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('schlechtere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('differenzierterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('flexiblerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('nachdrücklicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('populärer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('unüberwindbarer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('bombastischer', 'ADJ|Degree=Cmp'), 1),
#  (('gegensätzlicher', 'ADJ|Degree=Cmp'), 1),
#  (('bemerkenswerter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('wohlhabenderen', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('stärkerem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('genaueren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('früheren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('positiver', 'ADJ|Degree=Cmp'), 1),
#  (('älteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('jüngeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('weiteren', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 1),
#  (('weiteren', 'ADJ|Case=Dat|Degree=Cmp|Number=Plur'), 1),
#  (('zersplitterter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('transitorischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('verletzlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('schlechtere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('längeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('komplexer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('wagemutiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('innovativer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('sinnlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('subtiler', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('zufriedenstellenderen', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'),
#   1),
#  (('subtilste', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('strahlender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('interessanterer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('bequemeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('weitere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('tiefgreifendere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('flexibleren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('größeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('bessere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('niedrigeren', 'ADJ|Case=Dat|Degree=Cmp|Number=Plur'), 1),
#  (('zweitstärkste', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('sozialdemokratischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kooperativer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('leistungsfähiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('härterer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('größeren', 'ADJ|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('früheren', 'ADJ|Case=Dat|Degree=Cmp|Number=Plur'), 1),
#  (('strikter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('mäßigerem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('unfreundlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kürzerer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('engeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('letztere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('engere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('engeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('höherer', 'ADJ|Case=Gen|Degree=Cmp|Number=Plur'), 1),
#  (('älteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('schwächeres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('mühseliger', 'ADJ|Degree=Cmp'), 1),
#  (('kurzfristiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('effektivere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('breiteren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('scheinheiliger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('komplexeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('flacheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('lebhaftere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('düsterer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('günstigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('gedämpfteres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('geringere', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 1),
#  (('jüngere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('spätere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('niedrigeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('spontaner', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('ansteckender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('jüngere', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 1),
#  (('schärferes', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('längeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('tiefere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('stärkeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('letztere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('späteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('spätere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('schonungsloser', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('selbstbewußter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('bürgerlicher', 'ADJ|Degree=Cmp'), 1),
#  (('frischer', 'ADJ|Degree=Cmp'), 1),
#  (('klarerer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('empfänglicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kühleren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('frühere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('niedrigeres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('ernstere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('dauerhafter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('undeutlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('beliebter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('stärkeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('strengeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('liberaler', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('höheren', 'ADJ|Case=Nom|Degree=Cmp|Number=Plur'), 1),
#  (('ruhigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('genauere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('verwickelter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('lukrativere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('bedrückender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('strenger', 'ADJ|Degree=Cmp'), 1),
#  (('schärferen', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('härtere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('jüngere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('späteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('weniger', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('breiteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('leuchtenderer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('wichtigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('enttäuschender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('frühren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('gründlicher', 'ADJ|Degree=Cmp'), 1),
#  (('differenzierteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('schutzwürdiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('ärgerlicher', 'ADJ|Degree=Cmp'), 1),
#  (('wirksamer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('bereitwilliger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('höheren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('schwächeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('schwierigere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('niedrigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('ruhigeres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('umfassendere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('brisanter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('winzigerer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('edlere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('bessere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('dichtere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('tiefere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('substantieller', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('höheren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('kostengünstigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('spannender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('anziehender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('angemessener', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('moderner', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('zeitnahere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('magerer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('geschicktere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('markanter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('prosaischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('stilleren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('elegantere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('gruftiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('lauschigere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('trüber', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('günstigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('preiswerterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('langwelliger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('leistungsschwächer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('schlechtere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('brüchiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('nützlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('patriotischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('frühere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('billigerer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('besseren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('grauer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kleinere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('unbequemer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('monotoner', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kleinerer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('dynamischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('größerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('internationaler', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('größere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('wichtigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('neueren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('stärkerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('ausgeprägter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('unschärfer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('jüngere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('einschneidenderen', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('homogener', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('besseren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('heterogener', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('suggestivere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('sympathischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('energischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('verschiedener', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kleineren', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 1),
#  (('grauer', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('beeindruckender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kleineren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('öfteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('weltlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('spätere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('kompliziertere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('ungestümer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('besseren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('stoßfesteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('ärmere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('leichtere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('produktiver', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('weiteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('adäquater', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kleinkalibrigere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('zahlreicher', 'ADJ|Degree=Cmp'), 1),
#  (('subtilere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('aktiver', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('östlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('fester', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('wichtigerer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('reicheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('geringerer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('hübscher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('blöder', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('lustbetonter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('ärmere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('billigeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('trockener', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('ressourcenintensiveren',
#    'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'),
#   1),
#  (('bessere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('problematischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('älteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('neueren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('älters', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('jüngere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('selbstständiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('ähnlich', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('größeres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('einschneidender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kleineren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('menschlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('göttlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('härteren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('höheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('umweltverträglichere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'),
#   1),
#  (('kleineren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('preiswertere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('schnellere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('offeneren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('eigennütziger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('geringerer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('unklarer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('schärfere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('kräftigeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('neueren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('näherem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('neuerer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('gröber', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('späterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('kleinerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('niedrigere', 'ADJ|Case=Nom|Degree=Cmp|Number=Plur'), 1),
#  (('früherem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('komfortabler', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kälteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('kälteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('breiterer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('engeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('weiteren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('besseren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('geringeres', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('niedrigere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('seichtere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('früheren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('besseres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('neueren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('längeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('unattraktiver', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('härteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('anständigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('lichtere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('längeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('vorteilhafter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('aggressiveres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('kritischeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('größeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('konventioneller', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('breitgefächerter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('schwächere', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 1),
#  (('schwächerer', 'ADJ|Case=Gen|Degree=Cmp|Number=Plur'), 1),
#  (('surrealer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('mildere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('beherzter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('menschenscheuer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('inniger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('späterer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('leichteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('älterer', 'ADJ|Case=Gen|Degree=Cmp|Number=Plur'), 1),
#  (('schwerwiegender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('lebhafter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('klareren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('kühner', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('schwereren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('schlechteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('attraktivere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('schwächerer', 'ADJ|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('bekannter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('bedenklicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('zugeknöpfter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('härteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('schwächeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('wirkungsvoller', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('äußeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('gereizter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('deutlichere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('jüngeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('älteren', 'ADJ|Case=Nom|Degree=Cmp|Number=Plur'), 1),
#  (('flottere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('längeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('preisgünstigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('geringere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('härteres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('flexiblerer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('facettenreicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kompetenteres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('unangenehmer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('ursprünglicheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('sauberer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('stiller', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('mächtigeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('unbefangener', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('mittleren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('kostengünstigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('aggressiver', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('liberaleren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('frischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('härteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('weitere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('ruhiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('niedrigeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('lebhafteren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('soliderer', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('offenere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('stärkeres', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('späterer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('jüngeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('schwächere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('teurere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('höhere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('analytischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('pessimistischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('billigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('strengere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('dunkleres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('anstrengender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('klarer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('grösser', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('artgerechter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('frühere', 'ADJ|Case=Nom|Degree=Cmp|Number=Plur'), 1),
#  (('härtere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('mittlere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('gefährlicher', 'ADJ|Degree=Cmp'), 1),
#  (('kräftiger', 'ADJ|Degree=Cmp'), 1),
#  (('gewinnbringender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('schöneren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('größeren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('weiteren', 'ADJ|Case=Dat|Degree=Cmp|Number=Sing'), 1),
#  (('lustiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('wärmeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('sauerstoffhaltigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'),
#   1),
#  (('unterschiedlichere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('gemütlicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('leerer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('nähere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('entspannter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('feinere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('höheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('zuverlässiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('tieferen', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('affektfreier', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('fragwürdiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('größere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('schaler', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('umfassender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('dunkleren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('ärger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('flexiblere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('üppigere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('ältere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('kleinere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('dünneren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('fataler', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('weitere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('nächsten', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('attraktiveren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('strafferen', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('sanfteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('sarkastischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kritischer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('handfester', 'ADJ|Degree=Cmp'), 1),
#  (('entscheidender', 'ADJ|Degree=Cmp'), 1),
#  (('moderater', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('kleineren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('hoffnungsvoller', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('allgemeineren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('stärkerer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('effektiveres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('klarer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('klarere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('lukrativere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('intensivere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('ferneres', 'ADJ|Case=Acc|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('kürzeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('eigenständiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('weitreichenderem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('leichteren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('näheren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('offener', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('eindeutiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('jüngerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('jüngerer', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('harmlosere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('geringeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('stärkeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('selektiver', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('flotter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('transparenter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('näheren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('unbedenklicheren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('hörbarer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('höheres', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('preisgünstiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('internationaleren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('strenger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('konservativer', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('positivere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('ehrgeizigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('reibungsloseren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('größeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('ärmerer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('erstere', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 1),
#  (('dringender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('niedrigeren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('individueller', 'ADJ|Degree=Cmp'), 1),
#  (('ersteren', 'ADJ|Case=Dat|Degree=Cmp|Number=Plur'), 1),
#  (('letzteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('ersteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('sanfter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('schleppender', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('resoluter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('konzilianteren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('imposanter', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('rauhere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('breiterem', 'ADJ|Case=Dat|Degree=Cmp|Gender=Neut|Number=Sing'), 1),
#  (('heißere', 'ADJ|Case=Acc|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('dramatischer', 'ADJ|Degree=Cmp'), 1),
#  (('höheren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Neut|Number=Plur'), 1),
#  (('abhängiger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('anfälliger', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('umfangreicher', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('hektischeren', 'ADJ|Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('höherer', 'ADJ|Case=Gen|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('günstigeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('höhere', 'ADJ|Case=Acc|Degree=Cmp|Number=Plur'), 1),
#  (('angemesseneren', 'ADJ|Case=Acc|Degree=Cmp|Gender=Masc|Number=Sing'), 1),
#  (('bekannteren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Sing'), 1),
#  (('realistischeren', 'ADJ|Case=Dat|Degree=Cmp|Gender=Fem|Number=Plur'), 1),
#  (('flinkere', 'ADJ|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur'), 1),
#  (('ernster', 'ADJ|Degree=Cmp|Variant=Short'), 1),
#  (('längeren', 'ADJ|Case=Gen|Degree=Cmp|Gender=Neut|Number=Sing'), 1)]

# %%
de_sorted = list(filter(lambda c: not re.search(r'^ADJ', c[0][1]), de_sorted))

# %%
# nouns
# feminine version of nouns for occupations etc. add -in to the base form 
# gbnsz don't quite follow the rule (medizin, prinzessin) - keep in feminine form
female_nouns = list(filter(lambda c: re.search(r'^NOUN.*Case=Nom.*Gender=Fem.*Number=Sing', c[0][1]) and re.search(r'.*[^gbnsz]in$', c[0][0]), de_sorted))
for word in female_nouns:
    de_sorted.remove(word)
# add base feminine nouns
de_sorted += {((word[:-2], tag.replace("Gender=Fem", "Gender=Masc")), count) for (word, tag), count in female_nouns}

# %%
# weak nouns (the N-declension) take an "n" ending in all cases except nominative
weak_masc_nouns = list(filter(lambda c: re.search(r'^NOUN.*Case=Nom.*Gender=Masc.*Number=Sing', c[0][1]) and re.search(r'.*(e|ant|ent|ist|at|aut|ad)$', c[0][0]), de_sorted))

# Herz is the only non-masculine weak noun
weak_neut_nouns = list(filter(lambda c: re.search(r'^NOUN.*Case=Nom.*Gender=Neut.*Number=Sing', c[0][1]) and re.search('^herz$', c[0][0]), de_sorted))

# %%
# all nouns are capitalised in German - keep this in lexicon
lexicon += {(word.capitalize(), "NOUN|"+tag.split("Gender=")[1][0]+"|Weak") for (word, tag), _ in weak_masc_nouns + weak_neut_nouns}

# %%
de_sorted = list(filter(lambda c: not c in weak_masc_nouns+weak_neut_nouns, de_sorted))

# %%
# plural nouns - remove the stems and remove umlaut shifts where possible to get base form
plural_nouns = {word for (word, tag), _ in list(filter(lambda c: re.search(r'^NOUN.*Case=Nom.*Number=Plur', c[0][1]), de_sorted))}

# %%
split_plurals = [re.split(r'(e|e?n|er|s)$', word) for word in plural_nouns]

# %%
split_plurals
# Out:
# [['aserbaidschan', 'er', ''],
#  ['plän', 'e', ''],
#  ['inderinn', 'en', ''],
#  ['kleinstorganism', 'en', ''],
#  ['extrem', 'e', ''],
#  ['installation', 'en', ''],
#  ['schauprozess', 'e', ''],
#  ['vertragsstaat', 'en', ''],
#  ['däninn', 'en', ''],
#  ['aktionswoch', 'en', ''],
#  ['schlöss', 'er', ''],
#  ['überstund', 'en', ''],
#  ['phiol', 'en', ''],
#  ['regierend', 'en', ''],
#  ['abstimmung', 'en', ''],
#  ['schiffsfriedhöf', 'e', ''],
#  ['hutu'],
#  ['vers', 'e', ''],
#  ['bergbauer', 'n', ''],
#  ['sonderzahlung', 'en', ''],
#  ['landtagsausschüss', 'e', ''],
#  ['soziolog', 'en', ''],
#  ['saatmuschel', 'n', ''],
#  ['gehaltsforderung', 'en', ''],
#  ['ambulanz', 'en', ''],
#  ['idol', 'e', ''],
#  ['lakota'],
#  ['dino', 's', ''],
#  ['jahreszeit', 'en', ''],
#  ['anzeich', 'en', ''],
#  ['daunenbett', 'en', ''],
#  ['neugründung', 'en', ''],
#  ['halbwüchsig', 'e', ''],
#  ['verbandsvertret', 'er', ''],
#  ['mitarbeit', 'er', ''],
#  ['schlechtverdienend', 'e', ''],
#  ['vulv', 'en', ''],
#  ['hochschulsenat', 'e', ''],
#  ['neubürg', 'er', ''],
#  ['extremistengrupp', 'en', ''],
#  ['auslandsmärkt', 'e', ''],
#  ['qualifiziert', 'e', ''],
#  ['berufsprovokateur', 'e', ''],
#  ['seetransport', 'e', ''],
#  ['einschätzung', 'en', ''],
#  ['verteidigungsausgab', 'en', ''],
#  ['mott', 'en', ''],
#  ['wein', 'e', ''],
#  ['tourismusfachleut', 'e', ''],
#  ['auslieferungsanträg', 'e', ''],
#  ['bexbach', 'er', ''],
#  ['menschenmass', 'en', ''],
#  ['gegenmodell', 'e', ''],
#  ['waffenkäuf', 'e', ''],
#  ['kräft', 'e', ''],
#  ['gestalt', 'en', ''],
#  ['selbstversorg', 'er', ''],
#  ['festlandstürk', 'en', ''],
#  ['bundeswehrkasern', 'en', ''],
#  ['befund', 'e', ''],
#  ['nachtwach', 'en', ''],
#  ['isarwerk', 'e', ''],
#  ['erfolgsmeldung', 'en', ''],
#  ['glock', 'en', ''],
#  ['barrikad', 'en', ''],
#  ['christdemokrat', 'en', ''],
#  ['schauspiel', 'er', ''],
#  ['mieterhöhung', 'en', ''],
#  ['personalrät', 'e', ''],
#  ['privatbesuch', 'er', ''],
#  ['projekt', 'e', ''],
#  ['aktivität', 'en', ''],
#  ['universität', 'en', ''],
#  ['detonation', 'en', ''],
#  ['ankläg', 'er', ''],
#  ['staatsfunktionär', 'e', ''],
#  ['fernsehproduktion', 'en', ''],
#  ['grabstätt', 'en', ''],
#  ['bordellbetreib', 'er', ''],
#  ['kohlköpf', 'e', ''],
#  ['podiumsdiskussion', 'en', ''],
#  ['mütt', 'er', ''],
#  ['beobacht', 'er', ''],
#  ['zivilist', 'en', ''],
#  ['ombudsmänn', 'er', ''],
#  ['staatsgäst', 'e', ''],
#  ['zigarettenpackung', 'en', ''],
#  ['wildmuschel', 'n', ''],
#  ['ressortchef', 's', ''],
#  ['schattenriss', 'e', ''],
#  ['urwäld', 'er', ''],
#  ['finanzgericht', 'e', ''],
#  ['partnerländ', 'er', ''],
#  ['kameltreck', 's', ''],
#  ['geb', 'er', ''],
#  ['anlageinvestition', 'en', ''],
#  ['verdächtig', 'e', ''],
#  ['rosenheim', 'er', ''],
#  ['fertigungsstätt', 'en', ''],
#  ['rind', 'er', ''],
#  ['modemagazin', 'e', ''],
#  ['bemühung', 'en', ''],
#  ['einwendung', 'en', ''],
#  ['punk', 's', ''],
#  ['nachnam', 'en', ''],
#  ['einwohn', 'er', ''],
#  ['volksmass', 'en', ''],
#  ['naturheil', 'er', ''],
#  ['weis', 'en', ''],
#  ['iran', 'er', ''],
#  ['ordensschwester', 'n', ''],
#  ['werft', 'en', ''],
#  ['dienstleistungsunternehm', 'en', ''],
#  ['debatt', 'en', ''],
#  ['tierschütz', 'er', ''],
#  ['außenminist', 'er', ''],
#  ['ämt', 'er', ''],
#  ['blutgerinnsel'],
#  ['bankkund', 'en', ''],
#  ['lung', 'en', ''],
#  ['nettoeffekt', 'e', ''],
#  ['übersichtsspiegel'],
#  ['rationalisierungsmaßnahm', 'en', ''],
#  ['ausstellungsräum', 'e', ''],
#  ['warenhäus', 'er', ''],
#  ['schul', 'en', ''],
#  ['beträg', 'e', ''],
#  ['gipfelteilnehm', 'er', ''],
#  ['photographi', 'en', ''],
#  ['verletzt', 'e', ''],
#  ['tänz', 'er', ''],
#  ['wolkenbrüch', 'e', ''],
#  ['akzent', 'e', ''],
#  ['korrespondent', 'en', ''],
#  ['fahrräd', 'er', ''],
#  ['sinti'],
#  ['eckwert', 'e', ''],
#  ['heilmittel'],
#  ['goldsuch', 'er', ''],
#  ['karrikatur', 'en', ''],
#  ['beschwerdezentr', 'en', ''],
#  ['produktbeschreibung', 'en', ''],
#  ['strandkrabb', 'en', ''],
#  ['jungrind', 'er', ''],
#  ['sonderwünsch', 'e', ''],
#  ['maltes', 'er', ''],
#  ['umweltbeauftragt', 'e', ''],
#  ['gesicht', 'er', ''],
#  ['bahncardbesitz', 'er', ''],
#  ['muezzin', 's', ''],
#  ['streik', 's', ''],
#  ['medizin', 'er', ''],
#  ['parteitagsdelegiert', 'e', ''],
#  ['privatfirm', 'en', ''],
#  ['oppositionell', 'en', ''],
#  ['anhäng', 'er', ''],
#  ['bankschuld', 'en', ''],
#  ['wortschlacht', 'en', ''],
#  ['team', 's', ''],
#  ['kundgebungsteilnehm', 'er', ''],
#  ['grundsystem', 'e', ''],
#  ['areal', 'e', ''],
#  ['schirmherr', 'en', ''],
#  ['arzneimittel'],
#  ['trendmeldung', 'en', ''],
#  ['verkaufsläd', 'en', ''],
#  ['reih', 'en', ''],
#  ['produktivitätsvorteil', 'e', ''],
#  ['berufstätig', 'e', ''],
#  ['autoherstell', 'er', ''],
#  ['bedenk', 'en', ''],
#  ['meeresökosystem', 'e', ''],
#  ['stiefelschritt', 'e', ''],
#  ['statistik', 'en', ''],
#  ['gummiparagraph', 'en', ''],
#  ['spiel', 'er', ''],
#  ['mandant', 'en', ''],
#  ['spätschicht', 'en', ''],
#  ['wintersportl', 'er', ''],
#  ['röntgenfilm', 'e', ''],
#  ['kommentator', 'en', ''],
#  ['grundzüg', 'e', ''],
#  ['rechtschreibtest', 's', ''],
#  ['antwort', 'en', ''],
#  ['atomtest', 's', ''],
#  ['goldwäsch', 'er', ''],
#  ['nichtrauch', 'er', ''],
#  ['leistungsausgab', 'en', ''],
#  ['assekuranz', 'en', ''],
#  ['kelln', 'er', ''],
#  ['vorbehalt', 'e', ''],
#  ['touristenström', 'e', ''],
#  ['militärberichterstatt', 'er', ''],
#  ['fernstraß', 'en', ''],
#  ['firmenhochzeit', 'en', ''],
#  ['gerücht', 'e', ''],
#  ['erweiterung', 'en', ''],
#  ['bürgermeist', 'er', ''],
#  ['friedensvermittl', 'er', ''],
#  ['kulturverein', 'e', ''],
#  ['honorar', 'e', ''],
#  ['system', 'e', ''],
#  ['leuchttürm', 'e', ''],
#  ['gekniffen', 'en', ''],
#  ['ideolog', 'en', ''],
#  ['kettensäg', 'en', ''],
#  ['freidemokrat', 'en', ''],
#  ['schild', 'e', ''],
#  ['entsorgungsangebot', 'e', ''],
#  ['entlastungszüg', 'e', ''],
#  ['identität', 'en', ''],
#  ['firmenchef', 's', ''],
#  ['gericht', 'e', ''],
#  ['steuereinnahm', 'en', ''],
#  ['thrombos', 'en', ''],
#  ['blockad', 'en', ''],
#  ['armeehubschraub', 'er', ''],
#  ['bildgründ', 'e', ''],
#  ['stellvertret', 'er', ''],
#  ['unschlüssig', 'e', ''],
#  ['monokultur', 'en', ''],
#  ['mietverträg', 'e', ''],
#  ['kassanotierung', 'en', ''],
#  ['golf'],
#  ['ehepaar', 'e', ''],
#  ['zugäng', 'e', ''],
#  ['kapitalanlagevergeh', 'en', ''],
#  ['apothek', 'en', ''],
#  ['forderung', 'en', ''],
#  ['prüf', 'er', ''],
#  ['entdeckung', 'en', ''],
#  ['fortschritt', 'e', ''],
#  ['aktienpaket', 'e', ''],
#  ['wochenendausflügl', 'er', ''],
#  ['geschäftsbericht', 'e', ''],
#  ['gebet', 'e', ''],
#  ['filmstreif', 'en', ''],
#  ['betroffen', 'en', ''],
#  ['prax', 'en', ''],
#  ['ökonomi', 'en', ''],
#  ['rabattstaffel', 'n', ''],
#  ['devisenveränderung', 'en', ''],
#  ['gerät', 'e', ''],
#  ['nebenproduktion', 'en', ''],
#  ['mittät', 'er', ''],
#  ['grüppch', 'en', ''],
#  ['preisträg', 'er', ''],
#  ['versicher', 'er', ''],
#  ['düsenclipp', 'er', ''],
#  ['dauerarbeitsplätz', 'e', ''],
#  ['firmenkäuf', 'er', ''],
#  ['abmessung', 'en', ''],
#  ['galeri', 'en', ''],
#  ['unsterblich', 'en', ''],
#  ['baron', 'e', ''],
#  ['akteur', 'e', ''],
#  ['umfäng', 'e', ''],
#  ['wirtschaftsspion', 'e', ''],
#  ['paradiesruin', 'en', ''],
#  ['öl', 'e', ''],
#  ['weinhändl', 'er', ''],
#  ['stundenkilomet', 'er', ''],
#  ['prophezeiung', 'en', ''],
#  ['unwett', 'er', ''],
#  ['wähler', 'n', ''],
#  ['werbemittel'],
#  ['ausbildungsplätz', 'e', ''],
#  ['stahltank', 's', ''],
#  ['herbergsvät', 'er', ''],
#  ['faschist', 'en', ''],
#  ['firmenadress', 'en', ''],
#  ['verträg', 'e', ''],
#  ['bühn', 'en', ''],
#  ['standardantwort', 'en', ''],
#  ['strandhotel', 's', ''],
#  ['zwerg', 'e', ''],
#  ['wrack', 's', ''],
#  ['report', 'er', ''],
#  ['händ', 'e', ''],
#  ['verkehrssperr', 'en', ''],
#  ['literaturnobelpreisträg', 'er', ''],
#  ['anwärt', 'er', ''],
#  ['stein', 'e', ''],
#  ['wahl', 'en', ''],
#  ['campingplätz', 'e', ''],
#  ['kapitalerträg', 'e', ''],
#  ['verfahr', 'en', ''],
#  ['folgekost', 'en', ''],
#  ['granat', 'en', ''],
#  ['kassel', 'er', ''],
#  ['banknot', 'en', ''],
#  ['guatemaltek', 'en', ''],
#  ['domtürm', 'e', ''],
#  ['loip', 'en', ''],
#  ['straßengarküch', 'en', ''],
#  ['betrachtung', 'en', ''],
#  ['hör', 'er', ''],
#  ['problemfeld', 'er', ''],
#  ['arbeitgeberbeiträg', 'e', ''],
#  ['volksvertret', 'er', ''],
#  ['abschläg', 'e', ''],
#  ['widerständ', 'e', ''],
#  ['anschläg', 'e', ''],
#  ['beweis', 'e', ''],
#  ['skin', 's', ''],
#  ['geschäftskontakt', 'e', ''],
#  ['fenst', 'er', ''],
#  ['detailfrag', 'en', ''],
#  ['rent', 'en', ''],
#  ['konzernchef', 's', ''],
#  ['folterung', 'en', ''],
#  ['glanzpunkt', 'e', ''],
#  ['kolonialhäus', 'er', ''],
#  ['frontlini', 'en', ''],
#  ['packung', 'en', ''],
#  ['supermächt', 'e', ''],
#  ['verwend', 'er', ''],
#  ['niederlassung', 'en', ''],
#  ['wirtschaftsexpert', 'en', ''],
#  ['schwul', 'e', ''],
#  ['geldschein', 'e', ''],
#  ['territorialfrag', 'en', ''],
#  ['gewäss', 'er', ''],
#  ['laserstrahl', 'en', ''],
#  ['holzhandwerk', 'er', ''],
#  ['modelleisenbahn', 'en', ''],
#  ['zollbeamt', 'en', ''],
#  ['anpassungsschock', 's', ''],
#  ['kastani', 'en', ''],
#  ['bewertungsgrundsätz', 'e', ''],
#  ['leistung', 'en', ''],
#  ['lebensmittel'],
#  ['schiffbau', 'er', ''],
#  ['zulag', 'en', ''],
#  ['übernachtung', 'en', ''],
#  ['aktienkurs', 'e', ''],
#  ['kräh', 'en', ''],
#  ['verbrauchermärkt', 'e', ''],
#  ['cannabispflanz', 'en', ''],
#  ['gäul', 'e', ''],
#  ['ausstell', 'er', ''],
#  ['ortsbezeichnung', 'en', ''],
#  ['gebein', 'e', ''],
#  ['gemeindevertret', 'er', ''],
#  ['karteikart', 'en', ''],
#  ['mißhandlung', 'en', ''],
#  ['behandlung', 'en', ''],
#  ['verhaftung', 'en', ''],
#  ['vorgäng', 'e', ''],
#  ['filament', 'e', ''],
#  ['ausreisewillig', 'e', ''],
#  ['offizier', 'e', ''],
#  ['fusion', 'en', ''],
#  ['monopol', 'e', ''],
#  ['gefangen', 'en', ''],
#  ['globalverträg', 'e', ''],
#  ['fischknoch', 'en', ''],
#  ['automat', 'en', ''],
#  ['konzept', 'e', ''],
#  ['struktur', 'en', ''],
#  ['essen', 'er', ''],
#  ['interieur', 's', ''],
#  ['form', 'en', ''],
#  ['umweltstraftat', 'en', ''],
#  ['lins', 'en', ''],
#  ['dienstaltersstuf', 'en', ''],
#  ['vir', 'en', ''],
#  ['geschlechterverhältniss', 'e', ''],
#  ['dortmund', 'er', ''],
#  ['gestaltungskräft', 'e', ''],
#  ['konsumentenschütz', 'er', ''],
#  ['rumän', 'en', ''],
#  ['rücklag', 'en', ''],
#  ['erkenntniss', 'e', ''],
#  ['brösel'],
#  ['haitian', 'er', ''],
#  ['hauptrisik', 'en', ''],
#  ['konsequenz', 'en', ''],
#  ['lag', 'er', ''],
#  ['beschränkung', 'en', ''],
#  ['massenvernichtungswaff', 'en', ''],
#  ['gläubigerbank', 'en', ''],
#  ['adress', 'en', ''],
#  ['plädoyer', 's', ''],
#  ['raumfahrtfirm', 'en', ''],
#  ['finanzierungsquell', 'en', ''],
#  ['reduzierung', 'en', ''],
#  ['terrass', 'en', ''],
#  ['gläubigerstaat', 'en', ''],
#  ['becquerel'],
#  ['fehlurteil', 'e', ''],
#  ['urahn', 'en', ''],
#  ['führungsposition', 'en', ''],
#  ['massenentlassung', 'en', ''],
#  ['hundertausend', 'e', ''],
#  ['organism', 'en', ''],
#  ['vergewaltigung', 'en', ''],
#  ['geschäftsleut', 'e', ''],
#  ['auffassung', 'en', ''],
#  ['detailregelung', 'en', ''],
#  ['landbesetzung', 'en', ''],
#  ['rohr', 'e', ''],
#  ['reinigungsanlag', 'en', ''],
#  ['senator', 'en', ''],
#  ['folter', 'er', ''],
#  ['bundesländ', 'er', ''],
#  ['buss', 'e', ''],
#  ['realpolitik', 'er', ''],
#  ['strafverfolg', 'er', ''],
#  ['wettbewerb', 'e', ''],
#  ['kerz', 'en', ''],
#  ['untertitel'],
#  ['revisionist', 'en', ''],
#  ['impuls', 'e', ''],
#  ['vision', 'en', ''],
#  ['lederhos', 'en', ''],
#  ['unionist', 'en', ''],
#  ['frau', 'en', ''],
#  ['ärzt', 'e', ''],
#  ['chirurg', 'en', ''],
#  ['netzwerk', 'e', ''],
#  ['ureinwohn', 'er', ''],
#  ['verbindlichkeit', 'en', ''],
#  ['foto', 's', ''],
#  ['rivalität', 'en', ''],
#  ['vermiet', 'er', ''],
#  ['ngo'],
#  ['siedl', 'er', ''],
#  ['entsorgungsproblem', 'e', ''],
#  ['lett', 'en', ''],
#  ['bed'],
#  ['nachfolgestaat', 'en', ''],
#  ['energieeinsparpotential', 'e', ''],
#  ['preismechanism', 'en', ''],
#  ['entwicklung', 'en', ''],
#  ['wander', 'er', ''],
#  ['friedensgespräch', 'e', ''],
#  ['glasbläs', 'er', ''],
#  ['prozentpunkt', 'e', ''],
#  ['hilfsgüt', 'er', ''],
#  ['witwenverbrennung', 'en', ''],
#  ['streifzüg', 'e', ''],
#  ['profi', 's', ''],
#  ['personalcomput', 'er', ''],
#  ['dokumentarist', 'en', ''],
#  ['kolonialwar', 'en', ''],
#  ['antragsfrist', 'en', ''],
#  ['regim', 'e', ''],
#  ['zirkel'],
#  ['weltorganisation', 'en', ''],
#  ['wandmalerei', 'en', ''],
#  ['markterschließungsstrategi', 'en', ''],
#  ['forschungsgroßgerät', 'e', ''],
#  ['guru', 's', ''],
#  ['kazik', 'en', ''],
#  ['flasch', 'en', ''],
#  ['ferienregion', 'en', ''],
#  ['extrasendung', 'en', ''],
#  ['bränd', 'e', ''],
#  ['schimpforgi', 'en', ''],
#  ['neueinstellung', 'en', ''],
#  ['koalitionsfraktion', 'en', ''],
#  ['vorfäll', 'e', ''],
#  ['drückeberg', 'er', ''],
#  ['job', 's', ''],
#  ['karrieregedank', 'en', ''],
#  ['verankerung', 'en', ''],
#  ['forschungsprojekt', 'e', ''],
#  ['unionsstrateg', 'en', ''],
#  ['umwälzung', 'en', ''],
#  ['emotion', 'en', ''],
#  ['initiativ', 'en', ''],
#  ['polizeipräsidentinn', 'en', ''],
#  ['gehorsamspflicht', 'en', ''],
#  ['industriestaat', 'en', ''],
#  ['filmtitel'],
#  ['hauptroll', 'en', ''],
#  ['katalogseit', 'en', ''],
#  ['traub', 'en', ''],
#  ['westkolleg', 'en', ''],
#  ['them', 'en', ''],
#  ['erwachsen', 'en', ''],
#  ['scheidungsfrag', 'en', ''],
#  ['bankdarleh', 'en', ''],
#  ['schützengräb', 'en', ''],
#  ['fingerübung', 'en', ''],
#  ['stimmberechtigt', 'en', ''],
#  ['ossi', 's', ''],
#  ['voraussetzung', 'en', ''],
#  ['kriegsschauplätz', 'e', ''],
#  ['park', 's', ''],
#  ['nutzungspreis', 'e', ''],
#  ['rallyefahr', 'er', ''],
#  ['ortsverein', 'e', ''],
#  ['steuerausfäll', 'e', ''],
#  ['verschlechterung', 'en', ''],
#  ['entscheidungsverfahr', 'en', ''],
#  ['sportclub', 's', ''],
#  ['stammkund', 'en', ''],
#  ['kanzlergespräch', 'e', ''],
#  ['unzufriedenheit', 'en', ''],
#  ['bundeswehrmaschin', 'en', ''],
#  ['gegenmaßnahm', 'en', ''],
#  ['verschnaufpaus', 'en', ''],
#  ['vogelart', 'en', ''],
#  ['schienbeinschon', 'er', ''],
#  ['bettenkapazität', 'en', ''],
#  ['werbeagentur', 'en', ''],
#  ['tarifbestimmung', 'en', ''],
#  ['paar', 'e', ''],
#  ['sabotageakt', 'e', ''],
#  ['betrügerei', 'en', ''],
#  ['spekulationsbewegung', 'en', ''],
#  ['jugendforsch', 'er', ''],
#  ['amtsvorgäng', 'er', ''],
#  ['anteilseign', 'er', ''],
#  ['versicherung', 'en', ''],
#  ['milliardär', 'e', ''],
#  ['ausgab', 'en', ''],
#  ['tonfolg', 'en', ''],
#  ['kohlezech', 'en', ''],
#  ['hemming', 'er', ''],
#  ['weis', 'e', ''],
#  ['umweltminist', 'er', ''],
#  ['wanderung', 'en', ''],
#  ['kerl', 'e', ''],
#  ['zypriot', 'en', ''],
#  ['front', 'en', ''],
#  ['wohnräum', 'e', ''],
#  ['belegschaftsvertret', 'er', ''],
#  ['rebanlag', 'en', ''],
#  ['rebstöck', 'e', ''],
#  ['einfamilienhäus', 'er', ''],
#  ['wildmuschelbänk', 'e', ''],
#  ['henk', 'er', ''],
#  ['mord', 'e', ''],
#  ['prognos', 'en', ''],
#  ['rollstühl', 'e', ''],
#  ['hochburg', 'en', ''],
#  ['häuser', 'n', ''],
#  ['ankündigung', 'en', ''],
#  ['schichtplän', 'e', ''],
#  ['käuf', 'e', ''],
#  ['anteilsverkäuf', 'e', ''],
#  ['windräd', 'er', ''],
#  ['internist', 'en', ''],
#  ['autobomb', 'en', ''],
#  ['päss', 'e', ''],
#  ['vorort', 'e', ''],
#  ['münchn', 'er', ''],
#  ['angriff', 'e', ''],
#  ['hypothek', 'en', ''],
#  ['tick', 'er', ''],
#  ['waffenexport', 'e', ''],
#  ['netzrechn', 'er', ''],
#  ['geldstraf', 'en', ''],
#  ['bildungskost', 'en', ''],
#  ['shareholder', 's', ''],
#  ['schwäch', 'en', ''],
#  ['portugies', 'en', ''],
#  ['judenhass', 'er', ''],
#  ['senatorinn', 'en', ''],
#  ['kassakurs', 'e', ''],
#  ['warnhinweis', 'e', ''],
#  ['klöst', 'er', ''],
#  ['auslassung', 'en', ''],
#  ['eigentüm', 'er', ''],
#  ['westfal', 'en', ''],
#  ['muschelfisch', 'er', ''],
#  ['erholungstag', 'e', ''],
#  ['dieselantrieb', 'e', ''],
#  ['eigentumswohnung', 'en', ''],
#  ['immobiliengeschäft', 'e', ''],
#  ['telekommunikationsbetrieb', 'e', ''],
#  ['leistungsausgrenzung', 'en', ''],
#  ['inhab', 'er', ''],
#  ['minist', 'er', ''],
#  ['einflüss', 'e', ''],
#  ['güt', 'er', ''],
#  ['raumfahr', 'er', ''],
#  ['papier', 'e', ''],
#  ['wolk', 'en', ''],
#  ['lebensläuf', 'e', ''],
#  ['nebenwirkung', 'en', ''],
#  ['hauptaktionär', 'e', ''],
#  ['gärt', 'en', ''],
#  ['anlagenbau', 'er', ''],
#  ['welt', 'en', ''],
#  ['körn', 'er', ''],
#  ['tablettencocktail', 's', ''],
#  ['folterinstrument', 'e', ''],
#  ['polizeibehörd', 'en', ''],
#  ['stammakti', 'en', ''],
#  ['komponent', 'en', ''],
#  ['götting', 'er', ''],
#  ['komödienfigur', 'en', ''],
#  ['bundesbehörd', 'en', ''],
#  ['woiwodschaft', 'en', ''],
#  ['funk', 'en', ''],
#  ['todesfäll', 'e', ''],
#  ['insass', 'en', ''],
#  ['kursavanc', 'en', ''],
#  ['werksferi', 'en', ''],
#  ['vermögensbildungsansätz', 'e', ''],
#  ['mask', 'en', ''],
#  ['technikbefürwort', 'er', ''],
#  ['wirtschaftsdat', 'en', ''],
#  ['chip', 's', ''],
#  ['landeskirch', 'en', ''],
#  ['kurdinn', 'en', ''],
#  ['schallplattenproduktion', 'en', ''],
#  ['autonomiebehörd', 'en', ''],
#  ['paradepferd', 'e', ''],
#  ['staatsbedienstet', 'e', ''],
#  ['quadratmeterpreis', 'e', ''],
#  ['gesprächspartn', 'er', ''],
#  ['hochschulgremi', 'en', ''],
#  ['älter', 'en', ''],
#  ['konservativ', 'e', ''],
#  ['goldgräb', 'er', ''],
#  ['gemeingüt', 'er', ''],
#  ['synagog', 'en', ''],
#  ['zeremoni', 'en', ''],
#  ['jekk', 'en', ''],
#  ['heereskontingent', 'e', ''],
#  ['studierend', 'e', ''],
#  ['sicherheitsdoktrin', 'en', ''],
#  ['versicherungsleistung', 'en', ''],
#  ['irritation', 'en', ''],
#  ['kommunikationsschwäch', 'en', ''],
#  ['acrylfarb', 'en', ''],
#  ['anmerkung', 'en', ''],
#  ['vergleich', 'e', ''],
#  ['familienfreund', 'e', ''],
#  ['wirtschaftsräum', 'e', ''],
#  ['vokalpart', 's', ''],
#  ['düsseldorf', 'er', ''],
#  ['kläranlag', 'en', ''],
#  ['kern', 'e', ''],
#  ['lügn', 'er', ''],
#  ['länd', 'er', ''],
#  ['allgemein', 'en', ''],
#  ['ungebildet', 'e', ''],
#  ['halobakteri', 'en', ''],
#  ['futtermittel'],
#  ['farm', 'en', ''],
#  ['weinanbaugebiet', 'e', ''],
#  ['träum', 'er', ''],
#  ['letzter', 'e', ''],
#  ['sicherheitsbehörd', 'en', ''],
#  ['abkomm', 'en', ''],
#  ['marokkan', 'er', ''],
#  ['fahnd', 'er', ''],
#  ['vermögenswert', 'e', ''],
#  ['stoßtrupp', 'en', ''],
#  ['glücksritt', 'er', ''],
#  ['ausrüstungsgegenständ', 'e', ''],
#  ['schwarz', 'e', ''],
#  ['gemüseexporteur', 'e', ''],
#  ['neu', 'en', ''],
#  ['agrarexporteur', 'e', ''],
#  ['hubschraub', 'er', ''],
#  ['liegenschaft', 'en', ''],
#  ['sitz', 'e', ''],
#  ['ausländ', 'er', ''],
#  ['exzess', 'e', ''],
#  ['versprech', 'en', ''],
#  ['praktik', 'en', ''],
#  ['kumpel'],
#  ['vorurteil', 'e', ''],
#  ['kreativ', 'e', ''],
#  ['gesamtkunstwerk', 'e', ''],
#  ['spatz', 'en', ''],
#  ['spezialist', 'en', ''],
#  ['streck', 'en', ''],
#  ['betriebsgewinn', 'e', ''],
#  ['bildwelt', 'en', ''],
#  ['riss', 'e', ''],
#  ['herrschaftsverhältniss', 'e', ''],
#  ['ruhezon', 'en', ''],
#  ['eigentumsverhältniss', 'e', ''],
#  ['regierungschef', 's', ''],
#  ['ermittl', 'er', ''],
#  ['strafricht', 'er', ''],
#  ['homosexuell', 'e', ''],
#  ['vermög', 'en', ''],
#  ['dampfsonderzüg', 'e', ''],
#  ['taschenkontroll', 'en', ''],
#  ['bedienstet', 'e', ''],
#  ['befreiung', 'en', ''],
#  ['belastung', 'en', ''],
#  ['parteitag', 'e', ''],
#  ['betreib', 'er', ''],
#  ['ersatzstoff', 'e', ''],
#  ['verhältniss', 'e', ''],
#  ['spekulation', 'en', ''],
#  ['helf', 'er', ''],
#  ['umweltstandard', 's', ''],
#  ['panikverkäuf', 'e', ''],
#  ['übergangsfrist', 'en', ''],
#  ['ritual', 'e', ''],
#  ['buchverlag', 'e', ''],
#  ['delegationsmitglied', 'er', ''],
#  ['reklameform', 'en', ''],
#  ['hautproblem', 'e', ''],
#  ['indizi', 'en', ''],
#  ['geschunden', 'en', ''],
#  ['einwegprodukt', 'e', ''],
#  ['umweltfolg', 'en', ''],
#  ['krankenschwester', 'n', ''],
#  ['transaktion', 'en', ''],
#  ['reiseziel', 'e', ''],
#  ['totalverweiger', 'er', ''],
#  ['uni', 's', ''],
#  ['wasserbäll', 'e', ''],
#  ['eingriff', 'e', ''],
#  ['energiekonzern', 'e', ''],
#  ['optimist', 'en', ''],
#  ['originaltext', 'e', ''],
#  ['gefängnisstraf', 'en', ''],
#  ['mehrheitbeschaff', 'er', ''],
#  ['holzwann', 'en', ''],
#  ['kommando', 's', ''],
#  ['copyright'],
#  ['zionist', 'en', ''],
#  ['steuergeld', 'er', ''],
#  ['festivalmitarbeit', 'er', ''],
#  ['schalt', 'er', ''],
#  ['erwartung', 'en', ''],
#  ['telefonteilnehm', 'er', ''],
#  ['bericht', 'e', ''],
#  ['zeit', 'en', ''],
#  ['werk', 'e', ''],
#  ['zuständigkeit', 'en', ''],
#  ['containerkrän', 'e', ''],
#  ['kohlekraftwerk', 'e', ''],
#  ['bundesricht', 'er', ''],
#  ['expedition', 'en', ''],
#  ['landparti', 'en', ''],
#  ['vorlesungsverzeichniss', 'e', ''],
#  ['straftät', 'er', ''],
#  ['überschüss', 'e', ''],
#  ['jahr', 'en', ''],
#  ['grundfreiheit', 'en', ''],
#  ['theori', 'en', ''],
#  ['puff', 'er', ''],
#  ['feierlichkeit', 'en', ''],
#  ['uferzon', 'en', ''],
#  ['kurztrip', 's', ''],
#  ['tritt', 'e', ''],
#  ['mitarbeitergrupp', 'en', ''],
#  ['erkennungsstell', 'en', ''],
#  ['förderprogramm', 'e', ''],
#  ['herausforder', 'er', ''],
#  ['gaullist', 'en', ''],
#  ['vorstellung', 'en', ''],
#  ['reich', 'en', ''],
#  ['händl', 'er', ''],
#  ['bürozentr', 'en', ''],
#  ['humanwissenschaft', 'en', ''],
#  ['held', 'en', ''],
#  ['westl', 'er', ''],
#  ['landeskrankenhausgesellschaft', 'en', ''],
#  ['deserteur', 'e', ''],
#  ['wochenmagazin', 'e', ''],
#  ['klient', 'en', ''],
#  ['mindestentgelt', 'e', ''],
#  ['dm'],
#  ['führ', 'er', ''],
#  ['siren', 'en', ''],
#  ['mitfahr', 'er', ''],
#  ['bündnisgrün', 'en', ''],
#  ['steinkohleneinheit', 'en', ''],
#  ['kron', 'en', ''],
#  ['pathosformel', 'n', ''],
#  ['anbaut', 'en', ''],
#  ['regierungsoberhäupt', 'er', ''],
#  ['zwangsarbeit', 'er', ''],
#  ['dehnungsfug', 'en', ''],
#  ['konferenzdokument', 'e', ''],
#  ['gass', 'en', ''],
#  ['sinn', 'e', ''],
#  ['hauptamtlich', 'en', ''],
#  ['schauspielhäus', 'er', ''],
#  ['arbeit', 'er', ''],
#  ['landkart', 'en', ''],
#  ['nazi', 's', ''],
#  ['emir', 'e', ''],
#  ['stimmungstöt', 'er', ''],
#  ['zuffenhausen', 'er', ''],
#  ['sachverständig', 'en', ''],
#  ['stadtverordnet', 'e', ''],
#  ['zeitschrift', 'en', ''],
#  ['demonstrant', 'en', ''],
#  ['mechanism', 'en', ''],
#  ['kulturdezernent', 'en', ''],
#  ['dimension', 'en', ''],
#  ['wildfremd', 'e', ''],
#  ['frequenz', 'en', ''],
#  ['perspektiv', 'en', ''],
#  ['asylsuchend', 'e', ''],
#  ['wettbewerbsbedingung', 'en', ''],
#  ['maskerad', 'en', ''],
#  ['jahr', 'e', ''],
#  ['keramik', 'er', ''],
#  ['tot', 'en', ''],
#  ['globalisierungsaspekt', 'e', ''],
#  ['pini', 'en', ''],
#  ['geißel', 'n', ''],
#  ['gehält', 'er', ''],
#  ['minut', 'en', ''],
#  ['verjährungsdat', 'en', ''],
#  ['vitaminpräparat', 'e', ''],
#  ['steuerbeamt', 'e', ''],
#  ['bombenattentat', 'e', ''],
#  ['sicherung', 'en', ''],
#  ['wahlberechtigt', 'en', ''],
#  ['gewalttätigkeit', 'en', ''],
#  ['umverteilung', 'en', ''],
#  ['alleinerziehend', 'e', ''],
#  ['rebell', 'en', ''],
#  ['link', 'en', ''],
#  ['rekurs', 'e', ''],
#  ['förder', 'er', ''],
#  ['höf', 'e', ''],
#  ['akt', 'en', ''],
#  ['minerali', 'en', ''],
#  ['unternehm', 'er', ''],
#  ['belegschaft', 'en', ''],
#  ['gestirn', 'e', ''],
#  ['schadstoff', 'e', ''],
#  ['konsument', 'en', ''],
#  ['textzeil', 'en', ''],
#  ['landesbeauftragt', 'e', ''],
#  ['arbeitsunfähigkeitsbescheinigung', 'en', ''],
#  ['ameis', 'en', ''],
#  ['konvention', 'en', ''],
#  ['ferienhäus', 'er', ''],
#  ['datenschutzbeauftragt', 'en', ''],
#  ['mineral', 'e', ''],
#  ['mikrob', 'en', ''],
#  ['unternehm', 'en', ''],
#  ['subvention', 'en', ''],
#  ['ausbild', 'er', ''],
#  ['gewinnzon', 'en', ''],
#  ['astronaut', 'en', ''],
#  ['bundeswehrsoldat', 'en', ''],
#  ['pfarrei', 'en', ''],
#  ['mobilfunkbetreib', 'er', ''],
#  ['umsatzgarant', 'en', ''],
#  ['verein', 'e', ''],
#  ['schluck', 'er', ''],
#  ['personalabbaumaßnahm', 'en', ''],
#  ['faser', 'n', ''],
#  ['schönheit', 'en', ''],
#  ['büch', 'er', ''],
#  ['nachbar', 'n', ''],
#  ['kinderschutzverbänd', 'e', ''],
#  ['indiovölk', 'er', ''],
#  ['mindeststandard', 's', ''],
#  ['republik', 'en', ''],
#  ['junk', 'er', ''],
#  ['neckermänn', 'er', ''],
#  ['bein', 'e', ''],
#  ['firm', 'en', ''],
#  ['bänk', 'e', ''],
#  ['feldweg', 'e', ''],
#  ['löhn', 'e', ''],
#  ['artikel'],
#  ['ausnahm', 'en', ''],
#  ['mistdossier', 's', ''],
#  ['zücht', 'er', ''],
#  ['brandanschläg', 'e', ''],
#  ['kurd', 'en', ''],
#  ['kolonialstaat', 'en', ''],
#  ['kamera', 's', ''],
#  ['propagandaorgan', 'e', ''],
#  ['prostituiert', 'e', ''],
#  ['fundi', 's', ''],
#  ['schimmelpilz', 'e', ''],
#  ['streichquartett', 'e', ''],
#  ['meinungsforsch', 'er', ''],
#  ['filmkritik', 'er', ''],
#  ['emigrant', 'en', ''],
#  ['sprach', 'en', ''],
#  ['jong', 'e', ''],
#  ['unterzeichn', 'er', ''],
#  ['tourne', 'en', ''],
#  ['transitreis', 'en', ''],
#  ['bezirk', 'e', ''],
#  ['schätzung', 'en', ''],
#  ['met', 'er', ''],
#  ['profil', 'e', ''],
#  ['narb', 'en', ''],
#  ['weindörf', 'er', ''],
#  ['wählerinn', 'en', ''],
#  ['inspektor', 'en', ''],
#  ['finanzierung', 'en', ''],
#  ['plakat', 'e', ''],
#  ['munitionsteil', 'e', ''],
#  ['briefträg', 'er', ''],
#  ['auslandsreis', 'en', ''],
#  ['direktion', 'en', ''],
#  ['bundesangestellt', 'e', ''],
#  ['diagonal', 'en', ''],
#  ['gefährdung', 'en', ''],
#  ['verleih', 'er', ''],
#  ['erdbeb', 'en', ''],
#  ['folgeschäd', 'en', ''],
#  ['umweltministertreff', 'en', ''],
#  ['cd', 's', ''],
#  ['maßstäb', 'e', ''],
#  ['interdependenz', 'en', ''],
#  ['erinnerung', 'en', ''],
#  ['qualifikation', 'en', ''],
#  ['staatsausgab', 'en', ''],
#  ['lebenszeich', 'en', ''],
#  ['biertrink', 'er', ''],
#  ['komposition', 'en', ''],
#  ['finanzierungsvorschläg', 'e', ''],
#  ['eindrück', 'e', ''],
#  ['vertret', 'er', ''],
#  ['brustkrebspatientinn', 'en', ''],
#  ['regung', 'en', ''],
#  ['tierkadav', 'er', ''],
#  ['verursach', 'er', ''],
#  ['comput', 'er', ''],
#  ['schwächst', 'en', ''],
#  ['schüss', 'e', ''],
#  ['kernelement', 'e', ''],
#  ['härtefäll', 'e', ''],
#  ['zeder', 'n', ''],
#  ['hungrig', 'en', ''],
#  ['inselgrupp', 'en', ''],
#  ['millionensumm', 'en', ''],
#  ['machthab', 'er', ''],
#  ['vorinstanz', 'en', ''],
#  ['korp', 's', ''],
#  ['verkaufszahl', 'en', ''],
#  ['transportcontain', 'er', ''],
#  ['postberg', 'e', ''],
#  ['fossili', 'en', ''],
#  ['kunsthändl', 'er', ''],
#  ['straf', 'en', ''],
#  ['lohnnebenkost', 'en', ''],
#  ['halogenverbindung', 'en', ''],
#  ['komponist', 'en', ''],
#  ['lüft', 'en', ''],
#  ['hauptwerk', 'e', ''],
#  ['bauleut', 'e', ''],
#  ['wertberichtigung', 'en', ''],
#  ['stabilitätsanstrengung', 'en', ''],
#  ['einkommensschwach', 'e', ''],
#  ['ratt', 'en', ''],
#  ['meeresforsch', 'er', ''],
#  ['neuling', 'e', ''],
#  ['landhäus', 'er', ''],
#  ['regierungspartei', 'en', ''],
#  ['atomexplosion', 'en', ''],
#  ['forst', 'en', ''],
#  ['resolution', 'en', ''],
#  ['eckpunkt', 'e', ''],
#  ['nachrichtenfaktor', 'en', ''],
#  ['entwicklungskost', 'en', ''],
#  ['uraufführung', 'en', ''],
#  ['löschzüg', 'e', ''],
#  ['politikernam', 'en', ''],
#  ['ölgesellschaft', 'en', ''],
#  ['kassenwart', 'e', ''],
#  ['bürgersteig', 'e', ''],
#  ['hemmniss', 'e', ''],
#  ['meuter', 'er', ''],
#  ['pfeil', 'er', ''],
#  ['sanktion', 'en', ''],
#  ['bewohn', 'er', ''],
#  ['einbrüch', 'e', ''],
#  ['wahlkämpf', 'er', ''],
#  ['stipendiat', 'en', ''],
#  ['dicht', 'er', ''],
#  ['auftragsbüch', 'er', ''],
#  ['warnbrief', 'e', ''],
#  ['darstellung', 'en', ''],
#  ['gewohnheit', 'en', ''],
#  ['gastgeb', 'er', ''],
#  ['sprengsätz', 'e', ''],
#  ['person', 'en', ''],
#  ['sportfachhändl', 'er', ''],
#  ['präparat', 'e', ''],
#  ['sicherheitsbeamt', 'en', ''],
#  ['lpg', 's', ''],
#  ['backhilfsmittel'],
#  ['räd', 'er', ''],
#  ['werderan', 'er', ''],
#  ['rudiment', 'e', ''],
#  ['tarifabschlüss', 'e', ''],
#  ['kleinsthöf', 'e', ''],
#  ['investitionsentscheidung', 'en', ''],
#  ['zeugenaussag', 'en', ''],
#  ['platt', 'en', ''],
#  ['vorbot', 'en', ''],
#  ...]

# %%
singular_nouns = {word for (word, tag), _ in list(filter(lambda c: re.search(r'^NOUN.*Number=Sing', c[0][1]), de_sorted))}

# %%
singular_nouns
# Out:
# {'aluminium',
#  'kreditgeschäft',
#  'vereinbarung',
#  'gläubigerbank',
#  'homöopathie',
#  'hochschulfinanzierung',
#  'literaturwissenschaft',
#  'gegenfest',
#  'gebäudes',
#  'camp',
#  'überlebenskampf',
#  'vorrangs',
#  'zwischenlandung',
#  'vorurteilslosigkeit',
#  'prüfungskommission',
#  'gesamtkalkulation',
#  'computerprogramm',
#  'familienfeier',
#  'glückshormon',
#  'kampfliedes',
#  'chiphersteller',
#  'tuns',
#  'hochmittelalters',
#  'angleichungsprozeß',
#  'wiederbelebung',
#  'nettoertrag',
#  'handschrift',
#  'kennzeichnungspflicht',
#  'punkt',
#  'thron',
#  'relativisten',
#  'eindringlings',
#  'ethos',
#  'nachkriegsperiode',
#  'begegnungsstätte',
#  'beheizen',
#  'experimentelle',
#  'südstadt',
#  'reiterstandbild',
#  'trudeln',
#  'außenstehenden',
#  'quartel',
#  'debüt',
#  'soldatenschutz',
#  'fehlschlags',
#  'frauenjury',
#  'ozeanschiff',
#  'schlingel',
#  'staatsgründers',
#  'namensgebung',
#  'armseligkeit',
#  'stabilitätspakt',
#  'mandanten',
#  'mitgefühl',
#  'stehlen',
#  'strafjustiz',
#  'tier',
#  'ausgabenseite',
#  'atomtestprogramm',
#  'kilometerpreises',
#  'verschwindenlassen',
#  'einmalzahlung',
#  'postdienstchef',
#  'europareservat',
#  'preisträger',
#  'sinnlosigkeit',
#  'kausalität',
#  'technikbewußtsein',
#  'anwerbung',
#  'halbdunkel',
#  'achtung',
#  'telefontochter',
#  'stopfen',
#  'weltrang',
#  'stange',
#  'tv',
#  'nachrichtendienstes',
#  'äußerung',
#  'hund',
#  'ja',
#  'budgetrechts',
#  'militärgerät',
#  'fördersumme',
#  'gründungsgedanken',
#  'internationalisierung',
#  'konzerns',
#  'melange',
#  'neuerung',
#  'wildbahn',
#  'unbedenklichkeit',
#  'ergebnisswing',
#  'bluse',
#  'anmeldung',
#  'methapysik',
#  'lebensmittelkonzerns',
#  'wache',
#  'uhrzeit',
#  'megatrend',
#  'großmacht',
#  'vernichtungswahlkampf',
#  'oberelfe',
#  'wachtmeister',
#  'dispersion',
#  'strukturgeschichte',
#  'betroffenheit',
#  'stahlgruppe',
#  'vernehmen',
#  'sozialabbau',
#  'zivilcourage',
#  'vorläuferpapier',
#  'untertitel',
#  'lektion',
#  'oberschicht',
#  'produktionsfirma',
#  'zusammenhalts',
#  'symbolspiel',
#  'energieberatung',
#  'insistenz',
#  'jacke',
#  'siedler',
#  'fleckchen',
#  'kennzeichnung',
#  'pfuhlartige',
#  'fernsehen',
#  'naturalientausch',
#  'reichspräsidenten',
#  'hochschulausbildung',
#  'organisationsgrad',
#  'großstadtambiente',
#  'underground',
#  'gewerkschaftstages',
#  'glasbläserei',
#  'wahlniederlage',
#  'vorbedingung',
#  'verfassungsrevision',
#  'hauptmotor',
#  'erstarken',
#  'energieersparnis',
#  'mörders',
#  'auslegung',
#  'bewährtes',
#  'muskelshirt',
#  'markts',
#  'flirt',
#  'trennung',
#  'verhältnis',
#  'spitzenkandidatur',
#  'unzahl',
#  'verlustzone',
#  'fledermaus',
#  'erziehungstheorie',
#  'bundesarbeitsgericht',
#  'zaun',
#  'auslandsredaktion',
#  'turnhalle',
#  'zwangseinlage',
#  'fachdisziplin',
#  'kernwaffenfabrik',
#  'deutschlandlied',
#  'hochschulrektorenkonferenz',
#  'treppchen',
#  'gemisch',
#  'kreditgewerbe',
#  'ausverkauf',
#  'lohnfortzahlung',
#  'wassermotorradfahren',
#  'sterbestadt',
#  'gast',
#  'mietshauses',
#  'austritt',
#  'umbaus',
#  'gebetsmühle',
#  'tanzes',
#  'wahlmöglichkeit',
#  'strafverbüßung',
#  'domstadt',
#  'reorganisation',
#  'dahinsterbende',
#  'jahresmitte',
#  'einzelfallgerechtigkeit',
#  'treppenhaus',
#  'privatisierungsbehörde',
#  'koalitionsspitze',
#  'eisbahn',
#  'weinberg',
#  'investmentarm',
#  'rückversicherung',
#  'kontrollposten',
#  'italienischen',
#  'fluchtlinie',
#  'ursuppe',
#  'mittelstandsdelegation',
#  'agitprop',
#  'keramik',
#  'programmarbeit',
#  'gesamtwerk',
#  'eröffnungsveranstaltung',
#  'betäubungsmittelgesetzes',
#  'giftlein',
#  'ausgrabung',
#  'letztbegründung',
#  'berufsstand',
#  'hausbesitzer',
#  'urlauberspezies',
#  'bewährungssstrafe',
#  'würdigung',
#  'dekret',
#  'restrisiko',
#  'glaubwürdigkeit',
#  'milz',
#  'nebensaison',
#  'arbeitsrings',
#  'graf',
#  'reservierung',
#  'marionettenspielvariante',
#  'liebesaffäre',
#  'artillerie',
#  'provinzstadt',
#  'innenminister',
#  'laufzeit',
#  'plutoniumschmuggel',
#  'zunft',
#  'historienmalerei',
#  'polizeikreise',
#  'anlagewertes',
#  'ungehorsams',
#  'obdach',
#  'vertrauensverlust',
#  'zusammenlebens',
#  'präkambrium',
#  'kriminalamt',
#  'gerste',
#  'ballett',
#  'entindustriealisierung',
#  'öffentlichkeitscharakter',
#  'alb',
#  'staatsanteil',
#  'handlungsreisender',
#  'seenplatte',
#  'vorgehensweise',
#  'wüstensand',
#  'sozialverband',
#  'insektizid',
#  'scheitelhöhe',
#  'gerangel',
#  'rasengrün',
#  'verrat',
#  'offensichtlichkeit',
#  'verletzung',
#  'frauenarbeitslosigkeit',
#  'parteispitze',
#  'betonarchitektur',
#  'rückfall',
#  'medientrivialität',
#  'neugeschäftsschwäche',
#  'sachverhalts',
#  'winterhalbjahr',
#  'rotstift',
#  'leid',
#  'berglandschaft',
#  'eröffnungsbeschluß',
#  'rechtsunsicherheit',
#  'wertschätzung',
#  'erlaß',
#  'hauptbühne',
#  'anästhesie',
#  'emblem',
#  'wachmanns',
#  'zahnersatz',
#  'bürokommunikation',
#  'zeitgeist',
#  'pigmentepithel',
#  'namensliste',
#  'erbschaftssteuer',
#  'zweideutigkeit',
#  'medienhauses',
#  'saat',
#  'novemberkälte',
#  'klinkenputzen',
#  'crew',
#  'asienkrise',
#  'krieges',
#  'verursacherin',
#  'mitternacht',
#  'schnapsbude',
#  'demokratiespiel',
#  'polizeioffizier',
#  'marshall',
#  'herzens',
#  'zweiakters',
#  'mitgefangener',
#  'spielbank',
#  'lebensabend',
#  'bezeichnung',
#  'kontroverse',
#  'bemerkung',
#  'stab',
#  'räuberpistole',
#  'kleinstaats',
#  'gegenkongresses',
#  'raketenprogramm',
#  'lageregelung',
#  'landfriedensbruch',
#  'wahlkampagne',
#  'allroundkünstler',
#  'vorstandsetage',
#  'bezwinger',
#  'jubel',
#  'unruhefaktor',
#  'projektteam',
#  'subsidiarität',
#  'kreditfähigkeit',
#  'gastgeber',
#  'lebenserwartung',
#  'arbeitsteilung',
#  'gegenrichtung',
#  'finanzkonsortium',
#  'abstimmungsniederlage',
#  'südrand',
#  'abfallbeseitigung',
#  'angehörigen',
#  'landesvorsitzenden',
#  'nettoeffekt',
#  'nazi',
#  'absenkung',
#  'ernüchterung',
#  'verschwörerbande',
#  'dachverbandes',
#  'leutnant',
#  'kleiderordnung',
#  'mittelstandes',
#  'gartenbau',
#  'vererbung',
#  'angenehme',
#  'termin',
#  'haupthormon',
#  'hauptgeschäftsstelle',
#  'visumspflicht',
#  'delta',
#  'asylbewerberheim',
#  'brutalität',
#  'wirtschaftskriminalität',
#  'flugzeugs',
#  'friedensgesellschaft',
#  'erblindung',
#  'superwahljahr',
#  'gewerbesteuer',
#  'tour',
#  'aufsichtsratsvorsitzende',
#  'jazzmusiker',
#  'spitzengespräch',
#  'episode',
#  'buschwerk',
#  'bonität',
#  'beruf',
#  'berge',
#  'angel',
#  'agonie',
#  'auslandshilfe',
#  'heckenschenke',
#  'subkultur',
#  'landkreis',
#  'mindesteinkommen',
#  'gatten',
#  'mißbrauch',
#  'seebestattung',
#  'algerier',
#  'oppositionsführer',
#  'wesen',
#  'informationszugang',
#  'bekämpfung',
#  'landschaftstyp',
#  'innenministeriums',
#  'gründung',
#  'belagerung',
#  'budgetdebatte',
#  'abgeltung',
#  'rats',
#  'volksfeind',
#  'kommunikationsminister',
#  'frauenkonferenz',
#  'benutzeroberfläche',
#  'erzengel',
#  'firmenchef',
#  'umweltschutzpreis',
#  'vollzahler',
#  'republik',
#  'industriesystems',
#  'graupappel',
#  'kindergartenplatz',
#  'hymne',
#  'senator',
#  'fatale',
#  'passes',
#  'eiszeit',
#  'kleinformat',
#  'nettodefizit',
#  'schlag',
#  'besonderes',
#  'ödipuskomplexes',
#  'umsatzspitzenreiter',
#  'sensationswirkung',
#  'falles',
#  'präsidentenmaschine',
#  'restaurationsbewegung',
#  'kommandeurtagung',
#  'reserveoffizier',
#  'luxusschutz',
#  'ankündigung',
#  'langzeitwirkung',
#  'animation',
#  'verhängnisses',
#  'entschlußlosigkeit',
#  'asylverfahren',
#  'stellenabbaus',
#  'streifengang',
#  'brennelementewerk',
#  'tiernahrung',
#  'gottesdienst',
#  'interventionismus',
#  'flügelzange',
#  'plätschern',
#  'machtfrage',
#  'metallchef',
#  'empfinden',
#  'weltöffentlichtkeit',
#  'delegiertenbüros',
#  'kriegspropaganda',
#  'unfalls',
#  'kettchen',
#  'golfer',
#  'kammerspiel',
#  'arm',
#  'geschwindigkeitsvorsprung',
#  'erleben',
#  'tatsache',
#  'revolutionären',
#  'jahresspende',
#  'buchbildung',
#  'einsatzleiters',
#  'öko',
#  'zusammenspiel',
#  'buchreihe',
#  'tauglichkeit',
#  'industrie',
#  'märchenprinzessin',
#  'versammlung',
#  'tastatur',
#  'ideal',
#  'produktion',
#  'freitag',
#  'geschäftsbereichs',
#  'steuerquotenerhöhung',
#  'anverwandler',
#  'zuschauer',
#  'rückgabe',
#  'unterjochung',
#  'plus',
#  'bude',
#  'reisens',
#  'revolutionsgardisten',
#  'personalbedarfs',
#  'souffleurkasten',
#  'bundesorchester',
#  'perfektion',
#  'dachkonstruktion',
#  'erlösanteil',
#  'gesetz',
#  'einengung',
#  'errungenschaft',
#  'nachrichtenwert',
#  'kammerstück',
#  'schwangerschaftsabbruchs',
#  'bankgewerbe',
#  'abwesenheit',
#  'arsch',
#  'gelände',
#  'urlaubsagentur',
#  'landeskenner',
#  'betriebswirtschaftsprofessor',
#  'wegkapelle',
#  'absakken',
#  'lebenslüge',
#  'zugriff',
#  'einführungslektion',
#  'volkskino',
#  'ernsthaftigkeit',
#  'süden',
#  'unabhängigkeit',
#  'referats',
#  'gesamtkapitalrendite',
#  'berufskleidung',
#  'grabkammer',
#  'steuersäkkel',
#  'schreibmaschine',
#  'eleganz',
#  'scheckheft',
#  'schimpfen',
#  'billion',
#  'kopiergeräteherstellers',
#  'ware',
#  'optimierung',
#  'landesjugendring',
#  'ungleichheit',
#  'mutterunternehmen',
#  'drucks',
#  'erinnerung',
#  'finanzskandal',
#  'möbelstück',
#  'verdienst',
#  'spezies',
#  'marktvehikel',
#  'melatonin',
#  'zustandekommen',
#  'pressebüro',
#  'malergewerbe',
#  'betriebsstätte',
#  'verhandlungsort',
#  'nothelfer',
#  'weltmarktebene',
#  'rechtsänderung',
#  'saarländers',
#  'telekommunikation',
#  'fang',
#  'nachrichtentechnik',
#  'urlaubsmark',
#  'beifahrersitz',
#  'feierabend',
#  'volk',
#  'anteilnahme',
#  'mündungsgebiet',
#  'liaison',
#  'hinterhalt',
#  'nachwuchsreservoir',
#  'premierminnisters',
#  'wochenzeitschrift',
#  'quotenfrau',
#  'flexibilisierungsspielraums',
#  'viertels',
#  'jahresbericht',
#  'kommunikationsmedium',
#  'vermögens',
#  'indianermissionsrats',
#  'selbstzerfleischung',
#  'ortstermin',
#  'strafgerichtshofs',
#  'rätselraten',
#  'appetitlosigkeit',
#  'klassikers',
#  'stahlfusion',
#  'differenzbetrag',
#  'festsetzung',
#  'hebräisch',
#  'meeres',
#  'schwulenzeitung',
#  'informationsoffensive',
#  'strandbezirk',
#  'anfangseinkommen',
#  'parteipräsidiums',
#  'fleischunternehmen',
#  'pipeline',
#  'koalitionskabinett',
#  'volksversammlung',
#  'löwenanteil',
#  'zwickmühle',
#  'gewerkschafsfunktionär',
#  'pacht',
#  'bundeswehrbeteiligung',
#  'körperorganisation',
#  'kommunistenhaß',
#  'staatsschutz',
#  'mittelverteilung',
#  'attentäters',
#  'zugfahrt',
#  'verknüpfung',
#  'zwischendividende',
#  'reifegrad',
#  'erlebnisse',
#  'geldnot',
#  'oberarm',
#  'fraktionsvorsitz',
#  'pille',
#  'vibrationstechnik',
#  'inflationsrate',
#  'monopolisten',
#  'garten',
#  'metzgerei',
#  'handelsbilanz',
#  'marktvolumen',
#  'löschen',
#  'wählergemeinschaft',
#  'momentaufnahme',
#  'primadonna',
#  'reduzierungsphase',
#  'axt',
#  'sinnfälligkeit',
#  'gesundheitspolitik',
#  'gebührenordnung',
#  'diskussionseinstieg',
#  'management',
#  'zugewinngemeinschaft',
#  'kreditwesen',
#  'bundesgerichtshofs',
#  'tracht',
#  'bezirks',
#  'mineralölkonzern',
#  'schlund',
#  'videos',
#  'sozialsystem',
#  'flugverbindung',
#  'wäscherin',
#  'anlauf',
#  'juniorpartner',
#  'west',
#  'sterilität',
#  'wissensgesellschaft',
#  'wahlgremium',
#  'besitzanspruch',
#  'verfassungsmäßigkeit',
#  'blitzvisite',
#  'andenken',
#  'hochstimmung',
#  'unwahrscheinliche',
#  'technologie',
#  'vordergrund',
#  'bundesvorsitzenden',
#  'nahverkehrstag',
#  'schutzfunktion',
#  'grundsteinlegung',
#  'exotik',
#  'bildungshungrigen',
#  'tennisspieler',
#  'militärgouverneurs',
#  'vize',
#  'befreiungsheeres',
#  'architekturbüro',
#  'generation',
#  'gasmarkt',
#  'schlichte',
#  'handgriff',
#  'sparguthaben',
#  'telefonbank',
#  'kulturbegriff',
#  'festnahme',
#  'theaterehe',
#  'armeevisite',
#  'entschädigung',
#  'sympathisantenpotential',
#  'uhrmachers',
#  'oberverwaltungsgerichts',
#  'betriebsbesichtigung',
#  'bauen',
#  'wirkungsgeschichte',
#  'kirchbau',
#  'regierungszeit',
#  'feindseligkeit',
#  'bestechungsverdacht',
#  'arbeitsplatzentwicklung',
#  'irrenhaus',
#  'katastrophenschutz',
#  'diensleistungssektor',
#  'blöße',
#  'anlagefirma',
#  'mieterverein',
#  'nachttisch',
#  'währungsinstitut',
#  'erlebnishorizonts',
#  'klappmesser',
#  'clown',
#  'fläche',
#  'erde',
#  'armutszeugnis',
#  'überschwemmung',
#  'widerwillen',
#  'stromes',
#  'beweis',
#  'videoinstallation',
#  'staatsratsgebäude',
#  'unvorhergesehenes',
#  'breitengrad',
#  'feldzug',
#  'normalisierung',
#  'sammler',
#  'begleiter',
#  'weinlokal',
#  'balsam',
#  'dschungel',
#  'rednertribüne',
#  'erzeugung',
#  'rückhalt',
#  'beratungssoftware',
#  'fachpublikum',
#  'staatschefs',
#  'parlamentarismus',
#  'standortsicherungsgesetzes',
#  'butter',
#  'gaseinsatz',
#  'kommunikationswissenschaft',
#  'gesellschaftspolitik',
#  'übelkeit',
#  'hearing',
#  'reformhektik',
#  'arbeitgeber',
#  'neuordnung',
#  'tankstelle',
#  'entstehens',
#  'unergründlichkeit',
#  'mülldeponie',
#  'einzelgänger',
#  'illegalität',
#  'bein',
#  'bayer',
#  'abschußliste',
#  'urlaub',
#  'ausbrechen',
#  'wissenschaftssenator',
#  'herabsetzung',
#  'geschehen',
#  'gerichtsurteil',
#  'lärmpegel',
#  'regierungskonferenz',
#  'eintrachtspieler',
#  'ampel',
#  'präsidentschaftskandidaten',
#  'klassenraum',
#  'mehrheitsbeschaffers',
#  'obszöne',
#  'dokumentarfilmfestival',
#  'ungeheuerlichkeit',
#  'kollaps',
#  'interpretation',
#  'ehedrama',
#  'presseagentur',
#  'berufsbeamtentums',
#  'troubadour',
#  'untergrundzirkel',
#  'stalinismus',
#  'dienstleistung',
#  'reisegruppe',
#  'ermittlungsrichter',
#  'forschungsgruppe',
#  'defensivgliederung',
#  'augenmaß',
#  'vorfeld',
#  'phallus',
#  'firmengründers',
#  'risikoabschirmung',
#  'stammhaus',
#  'äußeres',
#  'spurensuche',
#  'refinanzierung',
#  'hauptarbeitsgebiet',
#  'weinsortiment',
#  'polizeiinspektors',
#  'novelle',
#  'völkermordes',
#  'bundeshaushaltsordnung',
#  'sound',
#  'arbeitsloser',
#  'nachlaßverwaltung',
#  'sphinx',
#  'sicherheitsapparats',
#  'leitstand',
#  'aufzehren',
#  'delegiertenversammlung',
#  'asylrechts',
#  'aktionsplan',
#  'jahrhundertwende',
#  'thronrede',
#  'notenserie',
#  'kabinettsliste',
#  'germanistik',
#  'verstetigung',
#  'thermometer',
#  'entwurf',
#  'justizminister',
#  'langzeittest',
#  'tasache',
#  'wasserknappheit',
#  'transit',
#  'familienzusammenführung',
#  'todesfolge',
#  'doppelte',
#  'rot',
#  'ehrenmitglied',
#  'label',
#  'baugewerkschaft',
#  'munitionsstraße',
#  'bezirkschef',
#  'industriemacht',
#  'hormonpräparate',
#  'mezzostimme',
#  'rechtssystems',
#  'hörergeneration',
#  'autorenkreis',
#  'einwandes',
#  'formulierung',
#  'mandats',
#  'knall',
#  'direktbuchen',
#  'alter',
#  'grundstück',
#  'festhalten',
#  'gebäudebestandes',
#  'diptychon',
#  'umweltaktivistin',
#  'staudammprojekt',
#  'volkspolizisten',
#  'wertschöpfungspartei',
#  'polizeirecht',
#  'steuererhöhung',
#  'selbstbefragung',
#  'glaubwürdigkeitskrise',
#  'mal',
#  'dreiklang',
#  'vermittlungsausschusses',
#  'richterdelegation',
#  'nichtigkeit',
#  'lebensmittelhilfe',
#  'mittvierzigers',
#  'pflegeversicherung',
#  'körpers',
#  'privatkundschaft',
#  'planungsunsicherheit',
#  'ungeschick',
#  'nil',
#  'halbjahres',
#  'schuldengrenze',
#  'energieverbrauchschecks',
#  'regiearbeit',
#  'kurzschluß',
#  'musikwissenschaftler',
#  'reisegewerbe',
#  'kürzungsquote',
#  'einschüchterungskampagnen',
#  'erreichbarkeit',
#  'anschlags',
#  'schrecklichen',
#  'vermögensbildung',
#  'fernziel',
#  'kochgeschirr',
#  'parteiführung',
#  'ausbreitung',
#  'großveranstaltung',
#  'wasserzeichen',
#  'tafelsilbers',
#  'auseinandersetzung',
#  'grenzbeamter',
#  'bombenattentat',
#  'unterhaltungsunternehmen',
#  'quatsch',
#  'naturschlandschaft',
#  'wahrung',
#  'kupferblech',
#  'schiffahrt',
#  'friedensvertrages',
#  'entschädigungsregelung',
#  'faszination',
#  'schwarzgeld',
#  'vorwort',
#  'materialaufwand',
#  'zirkuswelt',
#  'fachseminar',
#  'ungewisse',
#  'mehrwert',
#  'wallfahrt',
#  'nachkriegsgeschichte',
#  'schiffbaubetrieb',
#  'schreckensszenario',
#  'präsidentenkandidatur',
#  'obersatz',
#  'begehren',
#  'bundesinstitut',
#  'editionsprojekt',
#  'protektionismus',
#  'finanzhilfe',
#  'übergangs',
#  'küstenstreifen',
#  'mindestaltersgrenze',
#  'zusammenlegen',
#  'mainmetropole',
#  'wachstumskraft',
#  'bußgeld',
#  'polizist',
#  'verbrennung',
#  'maschinenbauunternehmen',
#  'geißblatt',
#  'einbruch',
#  'nennung',
#  'bundesgrenzschutz',
#  'edelbariton',
#  'botschaftseingang',
#  'verfassungsinitiative',
#  'zurückhaltung',
#  'gewerkschaftschef',
#  'volksabstimmung',
#  'comtesse',
#  'wahlschlappe',
#  'herzinfarkt',
#  'klavierliteratur',
#  'cannabis',
#  'gruppenantrags',
#  'rechner',
#  'dokument',
#  'grundstimmung',
#  'trauerperiode',
#  'neubelebung',
#  'rednerpodium',
#  'skisport',
#  'ansprechpartner',
#  'staatsorchester',
#  'stützpunkt',
#  'verbrauch',
#  'wasserverbrauch',
#  'vermögensverwaltung',
#  'österreicher',
#  'industrieland',
#  'trockenheit',
#  'sparkassengruppe',
#  'jahrtausendwechsel',
#  'schriftstellers',
#  'kirchendienst',
#  'rücksitz',
#  'rückzahlung',
#  'mädchen',
#  'originaltitels',
#  'militärclique',
#  'staatskasse',
#  'anhang',
#  'strick',
#  'umweltverbrauch',
#  'spielchen',
#  'etage',
#  'zweistaatlichkeit',
#  'üppigkeit',
#  'heizen',
#  'konkurrenzsituation',
#  'rechts',
#  'öls',
#  'einstichstelle',
#  'gipfeltreffen',
#  'weltwettbewerbsfähigkeit',
#  'erbitterung',
#  'gedenkveranstaltung',
#  'rechnungsprüfungsausschuß',
#  'ökonomie',
#  'farbfernsehers',
#  'erhabenheit',
#  'traubenkirsche',
#  'versorgungsgebiet',
#  'volumen',
#  'unglück',
#  'kundenberatung',
#  'gemütszustands',
#  'ruhekissen',
#  'personenverkehr',
#  'bausch',
#  'erbin',
#  'pressekonferenz',
#  'tempo',
#  'preisgabe',
#  'gegnerschaft',
#  'haushaltskonflikt',
#  'nachrichtenoffizier',
#  'minderausgabe',
#  'bruchfestigkeit',
#  'regelungswut',
#  'nationalsozialismus',
#  'korrektheit',
#  'imagination',
#  'schandfleck',
#  'budgetvolumen',
#  'machtentfaltung',
#  'atomstreitmacht',
#  'entstehungsprozeß',
#  'gewerkschaftsverband',
#  'befehlston',
#  'filzes',
#  'zucker',
#  'postbank',
#  'finanzkonzept',
#  'vorstufe',
#  'stoffumsatz',
#  'reformwerks',
#  'regierungsstils',
#  'kotau',
#  'personenführung',
#  'deckung',
#  'zumutung',
#  'intuition',
#  'filmemacher',
#  'telekommunikationsgesetz',
#  'sonnensystems',
#  'zeichens',
#  'korb',
#  'personalwechsel',
#  'verkehrsclub',
#  'zivilgesellschaft',
#  'massakers',
#  'asche',
#  ...}

# %%
# try reversing umlaut shifts - a bit crude and erroneously removes some umlauts
# but works reasonably well
def remove_umlaut(match_obj):
    umlaut_switch = {"ä": "a", "ö": "o", "ü": "u"}
    if match_obj.group() in umlaut_switch:
        return umlaut_switch[match_obj.group()]

# %%
# add plural nouns that only appear in the plural to lexicon
# cannot know the gender of these nouns since they do not appear in their singular form
unknown_plurals = {(re.sub(r'(ä|ö|ü)', remove_umlaut, word[0].capitalize()), ("NOUN|S|"+word[1] if len(word) > 1 else "")) for word in split_plurals if word[0] not in singular_nouns}
lexicon += unknown_plurals

# %%
# genitive noun endings generally add es or s in masculine and neuter nouns
# remove endings and then process them along with rest of singular nouns
genitive_nouns = [((re.split(r'(e?s)$', word)[0], tag), count) for (word, tag), count in 
                  list(filter(lambda c: re.search(r'^NOUN.*Case=Gen.*Gender=(Masc|Neut).*Number=Sing', c[0][1]), de_sorted))]

# %%
genitive_nouns
# Out:
# [(('jahr', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 150),
#  (('land', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 133),
#  (('präsidenten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 51),
#  (('staat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 45),
#  (('ministerpräsidenten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 40),
#  (('unternehmen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 32),
#  (('jahrhundert', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 32),
#  (('frieden', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 28),
#  (('haus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 26),
#  (('leben', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 26),
#  (('volk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 25),
#  (('parlament', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 24),
#  (('konzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 24),
#  (('mord', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 22),
#  (('tag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 21),
#  (('gericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 19),
#  (('institut', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 19),
#  (('regierungschef', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 18),
#  (('krieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 18),
#  (('bundestag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 17),
#  (('bundesverfassungsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 17),
#  (('gott', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 16),
#  (('bund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 16),
#  (('dienst', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 16),
#  (('kapital', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 15),
#  (('verband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 15),
#  (('vertrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 15),
#  (('parteitag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 15),
#  (('menschen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 14),
#  (('mann', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 14),
#  (('abkommen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 13),
#  (('amt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 13),
#  (('film', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 13),
#  (('asylrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 12),
#  (('prozess', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 12),
#  (('kind', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 12),
#  (('kanzler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 12),
#  (('regim', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 12),
#  (('außenminister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 12),
#  (('markt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 12),
#  (('kino', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 12),
#  (('sozialstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 12),
#  (('parteitag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 12),
#  (('kongress', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 12),
#  (('fernsehen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 11),
#  (('kollegen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 11),
#  (('buch', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 11),
#  (('verfahren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 11),
#  (('verdacht', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 10),
#  (('einzelhandel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 10),
#  (('problem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 10),
#  (('streit', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 10),
#  (('projekt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 10),
#  (('ministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 10),
#  (('teil', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 10),
#  (('gebäud', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 10),
#  (('wachstum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 10),
#  (('festival', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 10),
#  (('system', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 10),
#  (('handeln', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 9),
#  (('vater', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 9),
#  (('kabinett', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 9),
#  (('gesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 9),
#  (('recht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 9),
#  (('politiker', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 9),
#  (('senat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 9),
#  (('außenministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 9),
#  (('minister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 9),
#  (('rundfunk', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 9),
#  (('premierminister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 9),
#  (('werk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 9),
#  (('werk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 9),
#  (('mangel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 9),
#  (('währungsfond', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('sozialismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('konflikt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('westen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('theater', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 8),
#  (('gipfel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('publikum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 8),
#  (('anschlag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('ausschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('friedensprozess', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('geschehen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 8),
#  (('verteidigungsministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 8),
#  (('währungsinstitut', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 8),
#  (('kontinent', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 8),
#  (('umsatz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('landgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 7),
#  (('wort', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 7),
#  (('fall', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('abend', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('weltkrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('general', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('besuch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('osten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('könig', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('kommunismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('sprecher', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('staatspräsidenten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('rat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('haushalt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('bundeskanzler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('wirtschaftswachstum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 7),
#  (('bundesverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('tourismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('attentäter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('geld', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 7),
#  (('herrn', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('grundgesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 7),
#  (('tribunal', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 7),
#  (('schriftsteller', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('dichter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('arbeitgeber', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('universum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 7),
#  (('typ', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('bruttoinlandsprodukt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 7),
#  (('haushalt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('steuersystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('schaden', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('bundesland', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('dialog', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('gewerkschaftsbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('gipfeltreffen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('weg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('flughafen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('verein', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('handel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('manager', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('wettbewerb', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('bündniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('arbeitslosengeld', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('mißbrauch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('treffen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('betrieb', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('interess', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('bundesgerichtshof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('kapitalismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('vermeiden', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('ableger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('geist', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 6),
#  (('monat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('nationalsozialismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('netz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('gremium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('premier', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('staatschef', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('bürgermeister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('generalsekretär', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('bruttoinlandsprodukt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('arzt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('mitglied', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('gewinn', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('chef', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('gebiet', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('abgeordneten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('vorstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('reich', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('bauunternehmer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('zustand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('atomkraftwerk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('finanzministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('militär', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('umbruch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('drama', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('einsatz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('parteichef', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('auto', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('bundesverwaltungsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('bundesverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('einkommen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('stück', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('denken', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('soldaten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('alltag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('beamten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('ensembl', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('bundeskriminalamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('personal', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('konzept', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('urteil', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('vorgänger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('winter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('sozialsystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('betrug', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('europaparlament', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('partner', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('geschlecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('wandel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('dachverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('totschlag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('lama', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('wasser', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('weltmarkt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('autokonzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('führer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('jungen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('gegner', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('gespräch', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('unternehmer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('oberhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('attentat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('bericht', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('wissen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('patienten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('sektor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('schweigen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('bundespräsidenten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('künstler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('wirtschaftsgipfel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('nachrichtenmagazin', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('zentralrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('studium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('stoff', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('finanzminister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('kraftwerk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('gewerkschaftstag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('landtag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('verbrechen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('niederländer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('komite', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('zitat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('geheimdienst', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('belgier', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('rechnungshof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('gen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('alter', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('bundesinstitut', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('ladenschlußgesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('text', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('autor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('programm', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('parteivorsitzenden', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('kartellamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('existenzminimum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('süden', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('tierschutzbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('energieverbrauch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('anarchisten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('druck', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('territorium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('heer', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('ort', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('verband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('vorjahr', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('vorsitzenden', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('steuergeheimniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('welthandel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('geldverbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('gewerb', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('gefängniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('end', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('computer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('transfer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('geldhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('bürger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('willen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('anstoß', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('verwaltungsgerichtshof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('repräsentantenhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('rechnungswesen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('kollektiv', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('engagement', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('berg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('angebot', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('wohlstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('sozialstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('schloss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('angeklagten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('konkurrenten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('hauptverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('zentrum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('ökozentrum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('messer', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('kandidaten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('wirtschaftsmagazin', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('bruttosozialprodukt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('zeitalter', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('bau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('verrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('bündnisgebiet', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('arbeitnehmer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('weltkrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('massaker', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('untersuchungsausschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('jäger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('bundesinnenministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('gerichtshof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('urlaub', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('mittel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('vergleich', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('streik', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('ostblock', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('gastgeber', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('völkermord', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('gaststättenverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('verfassungsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('politbüro', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('geschäft', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('menschenrechtsverein', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('parlament', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('material', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('jäger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('kreuz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('bund', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('nobelpreis', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('führerschein', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('chao', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('branchenführer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('eigenkapital', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('norden', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('wohnungsbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('besitz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('arbeitgeberverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('fundamentalismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('verteidigungsminister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('rücktritt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('architekten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('journalisten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('bundestagswahlkampf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('präsidium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('standort', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('stück', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('schock', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('freund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('armeechef', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('intendanten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('wahlkampf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('flügel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('magazin', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('chemiekonzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('friedensabkommen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('nationalpark', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('jahrgang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('kloster', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('sozialabbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('mittelstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('philosophen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('rivalen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('verhältniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('volksgerichtshof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('feuer', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('gesamtverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('bundesamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('bedarf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('überschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('abbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('exil', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('professor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('schicksal', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('magistrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('strafrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('umweltschutz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('wahlkampf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('amtsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('bürgerkrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('wirtschaftsminister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('bundesstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('umbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('tod', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('fortschritt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('mathematikunterricht', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('bafög', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('nachwuchs', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('familienlastenausgleich', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('forum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('kaiserreich', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('verbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('ergebniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('justizministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('innenministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('staatsbürgerschaftsrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('modell', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('beschluss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('areal', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('sommer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('baulöwen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('raub', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('dollar', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('widerstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('namen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('städtetag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('bundesgerichtshof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('sportartikler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('inselstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('naturschutzbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('todesurteil', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('diktator', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('bewußtsein', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('ortsverein', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('rauchen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('prinzen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('völkermord', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('standort', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('hof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('strukturwandel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('hotel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('bundestag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('veranstalter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('satz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('steuerrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('karneval', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('aufschwung', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('widerstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('kreis', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('gasthof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('übergang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('chinabesuch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('kirchenvolksbegehren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('glauben', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('verständniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('besuch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('zweifel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('kunstmarkt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('haushaltsstreit', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('management', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('versagen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('aug', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('saarländer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('sohn', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('friedensplan', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('generalstab', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('tal', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('bundesrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('landeskriminalamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('spiel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('ball', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bundesministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('gehalt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('bundesgrenzschutz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('rechtssystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('konzil', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('leiden', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('subjekt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('nationalkongress', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('anschlag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('staatsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('polizeipräsidium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('versicherer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bündni', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('innenminister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('pharmaunternehmen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('krieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gebiet', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('arbeiter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('himmel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gegenkongress', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('verkauf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('visum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('kongreß', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('ministerrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('sozialprodukt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('zusammenwirken', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('trend', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('brüter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('zentralkomite', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('bundesrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('protokoll', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('karenztag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('lastwagen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gesetzgeber', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('congress', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('terrorismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('preisverfall', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('multi', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bruttosozialprodukt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('planeten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('wirtschaftsministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('arbeitsfrieden', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('kreditabwicklungsfond', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('sicherheitsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('großaktionär', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('reaktor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('binnenmarkt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('blatt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('handelstag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('hass', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('taifun', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('stellvertreter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('meinungsforschungsinstitut', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('gesundheitswesen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('zirku', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('abschiebegefängniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('gericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('unglück', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('thema', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('tiger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('ausgleich', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bundesdelegiertentag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('wirtschaften', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('finanzamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('mörder', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('fanatiker', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('sänger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('komponisten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('verlag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bewerber', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('freistaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('halbjahr', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('motor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('schauspiel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('gesamtkapital', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('geschäftsjahr', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('zugang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('tun', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('zuschauer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('aufsichtsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('verkehrsflugzeug', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('augenblick', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('film', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('buch', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('riesen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('volumen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('stand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('dramatiker', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('mißtrauen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('regierungsstil', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('menschenrechte', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('nachbarn', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('antrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('postministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('löwen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('außenamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('patriarchat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('ziel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('bundesverwaltungsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('rugbyspieler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('feldherrn', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('verstoß', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('blutfieber', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('oberverwaltungsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('atomkraftwerk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('dom', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('entstehen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('schutz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('großteil', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('flugzeug', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('grundstück', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('zwang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('aufstieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gesamtkonzept', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('umweltbewußtsein', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('lebensmittelkonzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('stil', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bundesverteidigungsministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'),
#   2),
#  (('konsum', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('wegfall', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('arbeitskreis', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('etat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('entsendegesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('gemeinwesen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('atlantik', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('solidaritätszuschlag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('supermarkt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('fluss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('schah', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('festspielhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('verlag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('jahrestag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bankrott', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('immobilienimperium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('bundeskriminalamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('bischof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('kirchentag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('finanzausschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('arbeitsvertrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('vorstandschef', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('verbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('vorhang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('spektrum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('gemütszustand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('rassismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('zusammenleben', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('äußeren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('studentenwerk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('zukunftsminister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('medium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('dokumentarfilm', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('kapitalmarkt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('branchenprimu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('stammhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('handelsblatt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('entsetzen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('judentum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('globu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('genr', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('museum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('begriff', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('königreich', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('landesparteitag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bundessozialgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('vertrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('wahlalter', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('bürgerkrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('verfall', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bruch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('immobilienspekulanten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('ehepaar', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('betäubungsmittelgesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('hanfanbauverbot', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('marktpotential', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('hanfanbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('beamtenrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('haushaltsrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('berufsbeamtentum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('roman', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('neuen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('blick', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('november', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('flugblatt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('angehörigen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('straftatbestand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('landesgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('gewissen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('job', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('se', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('staat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('merkantilismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('umweltbundesamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('einsparpotential', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('stromverbrauch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gebäudebestand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('verzicht', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('beschäftigungsverhältniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('zyklu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('kampf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gesetzgebungsverfahren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('beamtenbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('dienstrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('defekt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('staatenbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('landrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('schuldenlimit', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('raubüberfall', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('verwaltungsminister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bestehen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('paar', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('niedersachsen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('sozialdemokraten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('subkontinent', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('juristen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('flug', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('betrug', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('wohlfahrtsstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('direktor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('organisationsmilieu', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('bösen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('darben', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('militärregim', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('systemwettbewerb', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('betriebsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('fach', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('ermordeten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bauwerk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('ausmaß', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('verwalter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('preisindex', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('aktienkurs', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('inhalt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('amt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('indianermissionsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('herzinfarkt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gebäudekomplex', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('zoo', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('dänen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('autohersteller', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('produktivkapital', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('verteidigungsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('pensionsfond', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('delta', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('wohnungsbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('boom', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('landesbeauftragten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('lebensstil', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gestern', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('monopol', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('rechtsstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bürgerrechtler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bankhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('firmengründer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('terror', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('tamilen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('polizeisprecher', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('diebstahl', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('opfer', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('umgang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('monarchen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('neugeschäft', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('arbeitsministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('warenverkehr', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('zorn', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('ärger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('richter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bürgertum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('organismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('schlaf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('raffinement', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('plan', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('wert', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('lager', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('revier', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('nahverkehr', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gehalt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('finanzplatz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('wirtschaftsforum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('fisku', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('ganzen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('triebwerkhersteller', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('vorstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('landesrechnungshof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('beschuldigten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('clan', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('phänomen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('reiseziel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('stadtschloss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('sieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('wiederaufbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('tagungsort', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gefängnisdirektor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gegenfest', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('kindesmißbrauch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('übel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('erbarmen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('unionsvertrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('volksbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('admiral', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('gasprojekt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('wahlgesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('serienkiller', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('betriebsverfassungsgesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('betriebsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('zahlungsverkehr', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('internet', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('erachten', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('naturschutzring', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('jubiläum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('franc', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('euro', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('fehlbetrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('bip', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('tanztheater', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('brauhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('texaner', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('schatten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('teil', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('rechtsradikalismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('oberstadtdirektor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('branchenverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('freizeitsport', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('ball', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('kanton', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('mieterverein', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('freihafen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('aufruhr', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('ausnahmezustand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('ayatollah', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('revolutionsführer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('mittvierziger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('auftrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bereich', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('katastrophenreaktor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('sportfachhandel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('sportartikelmarkt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('sportartikelhandel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('stimmrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('neuaufbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('staatsetat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('vertragswerk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('aufsichtsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('privatisierungsprogramm', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('großreeder', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('tankerkönig', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('industrieministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('gouverneur', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('handelszentrum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('außenministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('friedensvertrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('standard', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('heim', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('mietwert', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('mietansatz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('schiff', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('devisenschmuggel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('totalitarismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('stadion', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('unterhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('fußballspieler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('flugzeug', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('gedenkhain', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('wald', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('hauskauf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('gruppenantrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('großkonzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('vergehen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('asylzentralgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('lufttransportgeschwader', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('schlußbericht', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('strafpunktesystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('register', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('viertel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('angriff', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('parteikongress', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('verbot', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('putsch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('etatdefizit', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('währungssystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('sozialisten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('zahlungsaufschub', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('banker', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('virenabwehrmittel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('präparat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('aid', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('aktientausch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('wirtschaftsembargo', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('rumpfstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('zyprioten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bundestaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('wochenlohn', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('radfahrer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('braunkohleabbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('versicherten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('fernsehgerätewerk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('rückgrat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('expertenwissen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('landesvorstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('parteiensystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('zeitdruck', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('gegenkongreß', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('zeremoniell', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('sherpa', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('wohlwollen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('lehrmeister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('wahlkämpfer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('palaver', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('absetzungsverfahren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('kontoinhaber', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('freibetrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('freibetrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('altersfreibetrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('kostensenkungsprogramm', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('golfkrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('flamingo', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('urankonzentrat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('ölmangel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('wirtschaftsprofessor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bürgerbegehren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('steuerzahlerbund', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('philosophieprofessor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('andenpakt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('strafpunktesystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('tunnel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('vermittlungsverfahren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('grauen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('riemen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('staatsanwalt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('strafprozeßrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('antiterrorgesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('auftrageingang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('arbeitsplatz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('wissenschaftsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('mutterland', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('verbot', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('kreditwesengesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('vizepräsidenten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('beweismittel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('sparprogramm', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('militärflugzeug', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('absturz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('elektrokonzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('wohneigentum', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('geldeingang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('rückzieher', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('koordinator', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('frachtdienst', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('staatssekretär', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('appell', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('rubel', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('diskussionsbedarf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('nachholbedarf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('spektakel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('nachschub', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('transportgwerb', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('ersatzbürgerkrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('konflikt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('entwicklungshilfeministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'),
#   1),
#  (('alternativen', 'NOUN|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing'), 1),
#  (('gesamtbestand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bilanzvermögen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('kartellamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('solidaritätskomite', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('kriminalprozess', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('vielvölkerstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('vermittlungsausschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('rekord', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('feiertag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('koreakrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('panzer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bosnienkrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('sicherheitsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('waffenstillstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('universitätsinstitut', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('abgeordnetenrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('eherecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('rabbinat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('beschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('autozulieferer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('landfriedensbruch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('kurdenstaat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('offizierskorp', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('befreiungsheer', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('planungsrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('altersjahrgang', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('fachhochschulprofessor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('protestmarsch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('unabhängigkeitstag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('botschafter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('punktesystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('ruin', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('zuständigkeitsbereich', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('popstar', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('gewicht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('abschlußbericht', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('medienreferenten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('befehlshaber', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('institut', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('internistenkongress', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('berufsverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('zirkuskönig', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('mädchen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('pharao', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('name', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('frauenanteil', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('aufruf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('reformer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('friedensaktivisten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('staatsterrorismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('gewaltpotential', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('länderrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('junikrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bauern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('vulkan', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('zollamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('inneninister', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('fehlverhalten', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('polizisten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('sozialarbeiter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('entwicklungsprogramm', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('streitkräfteamt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('arbeitsförderungsgesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('ausbildungsplatzangebot', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('flächentarifvertrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('luxusgeschöpf', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('outfit', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('todesschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bundsgrenzschutz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('lebensjahr', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('klassiker', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('donnerer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('regieteam', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('gerichtsreporter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('papageien', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('charm', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('reformkurs', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('postkommunisten', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bürgerrechtssprecher', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bundesvorstand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('wissenschaftler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('delegiertentag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('geldsegen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('schock', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('rat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('showbusines', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('album', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('risiko', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('thronprätentenden', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('tandem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('extremismu', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('friedensblock', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('anlass', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bundesgenossen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('friedenshandeln', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('nachrichtendienst', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('stimmenkauf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('hafen', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('kirchenparlament', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('seelsorgevertrag', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('musikleben', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('schüler', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('schmetterling', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('richterwahlausschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('kläger', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('stadtparlament', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('lärm', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('frachter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('seuchenzug', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bilanzierungsrecht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('zweisitzer', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('z', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('lüfter', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('minderheitssenat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  ...]

# %%
# plural suffixes for nouns taken from https://deutsch.lingolia.com/en/grammar/nouns-and-articles/plural
sing_nouns = list(filter(lambda c: re.search(r'^NOUN.*Case=(Nom|Acc|Dat).*Number=Sing', c[0][1]), de_sorted))
# add genitive nouns in their base form to the list of singular nouns
sing_nouns += genitive_nouns
# form plural with en
en_sing_nouns = list(filter(lambda c: 
            re.search(r'Gender=Fem', c[0][1]) and 
                re.search(r'(e|in|ion|ik|heit|keit|schaft|tät|ung)$', c[0][0]), sing_nouns))
lexicon += {(word.capitalize(), "NOUN|F|en") for (word, tag), _ in en_sing_nouns}

# %%
# form plural with e
e_sing_nouns = list(filter(lambda c: re.search(r'Gender=Masc', c[0][1]) and re.search(r'(eur|ich|ier|ig|ling|ör)$', c[0][0]), sing_nouns))
lexicon += {(word.capitalize(), "NOUN|M|e") for (word, tag), _ in e_sing_nouns}

# %%
# form plural with s
s_sing_nouns = list(filter(lambda c: re.search(r'[^aeiouy][aiouy]$', c[0][0]), sing_nouns))
lexicon += {(word.capitalize(), "NOUN|"+tag.split("Gender=")[1][0]+"|s" if "Gender" in tag else "NOUN|S|s") for (word, tag), _ in s_sing_nouns}

# %%
sing_nouns = set(sing_nouns) - set(en_sing_nouns) - set(e_sing_nouns) - set(s_sing_nouns)

# %%
# nouns that take no ending in the plural
no_m_sing_nouns = list(filter(lambda c: re.search(r'Gender=Masc', c[0][1]) and re.search(r'(el|en|er)$', c[0][0]), sing_nouns))
lexicon += {(word.capitalize(), "NOUN|M|no") for (word, tag), _ in no_m_sing_nouns}
no_n_sing_nouns = list(filter(lambda c: re.search(r'Gender=Neut', c[0][1]) and re.search(r'(chen|lein)$', c[0][0]), sing_nouns))
lexicon += {(word.capitalize(), "NOUN|N|no") for (word, tag), _ in no_n_sing_nouns}

# %%
sing_nouns = set(sing_nouns) - set(no_m_sing_nouns) - set(no_n_sing_nouns)

# %%
# plural form is not determined by the general rules for pluralisation for these nouns
sing_nouns
# Out:
# {(('marktakzeptanz', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('meer', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('ölkonzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('abhören', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('stickoxid', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('staatsakt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('jazzensemble', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('intellektuellenzirkus', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('minigolf', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('mißverständnis', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 4),
#  (('sorgenkind', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('west', 'NOUN|Case=Nom|Number=Sing'), 1),
#  (('gewissen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('archetyp', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('cent', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('zugverkehr', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('netzwerk', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('mitgliederstamm', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('klingel', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 2),
#  (('konzil', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('produktionsfortschritt', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('datenmißbrauch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('geplauder', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('referendum', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('marktwert', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('beugehaft', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 2),
#  (('verlauf', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 15),
#  (('vergleichszeitraum', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('bundesgebiet', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 5),
#  (('staatssozialismus', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('beschwerdebrief', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('rezept', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('bildformat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('fuss', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('einkommenszuwachs', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('konkurs', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 20),
#  (('steinkohlenbergbau', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('staatsreichtum', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('föderationsrat', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('glasspielzeug', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('königreich', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('altern', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('staatschef', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 8),
#  (('pilgerfahrt', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('fell', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('olympiazentrum', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('videosystem', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('eigenkapital', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('gesamtverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('kreditgeschäft', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('herzen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('karlsruhe', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('käuferschicht', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('bauen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('imitat', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('mut', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('urnengang', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 7),
#  (('wahlalter', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('edelmetallkonzern', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('soldatentum', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('zahlenwerk', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('massaker', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 5),
#  (('vorwahlkampf', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('nahverkehr', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 3),
#  (('hohn', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('weltkonjunktur', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('geschenk', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('steuerfall', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('idyll', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('biograph', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('küstenland', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('trotzalledem', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('schiff', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('ausnahmejahr', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('staatsbudget', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('erprobten', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('filmkunst', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('gebrauchtwagenmarkt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('vorschlag', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 9),
#  (('historismus', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('vermerk', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('mitternacht', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 4),
#  (('verständnis', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 8),
#  (('bundesverfassungsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('parlament', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 3),
#  (('krisentreffen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('wanderfreund', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('entwurf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 14),
#  (('unmögliches', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('knotenpunkt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('zeh', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('produktivitätsformel', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('hochschulerneuerungsprogramm', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'),
#   1),
#  (('asylantrag', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('gestaltungselement', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('fernsehduell', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('ungehorsam', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('gemeinschaftsabend', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('mittelmeer', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('erscheinungsbild', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 5),
#  (('karussell', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('doppelkrieg', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('protokoll', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('wohneigentum', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('teilzeitarbeit', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('team', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 9),
#  (('eros', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('familienministerium', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('geheimdienst', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 4),
#  (('gegengewicht', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('rechtsinstitut', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('geradestehen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('verkehrsclub', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('auftragsverhalten', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('comeback', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('inlandsflug', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('arm', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('lizenzmodell', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('burgtheater', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('rundumschutz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('werktag', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('doppelmordprozeß', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('junktim', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('turm', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('revolutionär', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('versandhaus', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('mitspracherecht', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('großaktionär', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('einheitspartei', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('problem', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 14),
#  (('schlaraffenland', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('stewardess', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('ordnungsgeld', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('fisch', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('irrfahrt', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('netzhaut', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('tanzensemble', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('jahresanfang', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('mittelalter', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 3),
#  (('romaviertel', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('nachtsicht', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('ausweg', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('jahrzehnt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('weihnachtsgeschäft', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('fahrzeug', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 4),
#  (('standardrepertoire', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('kür', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('konkurs', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('aufenthaltsrecht', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('reichskriegsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('kassensturz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('preis', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 26),
#  (('werke', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('wallfahrtsort', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('hansestadt', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 2),
#  (('hormonpräparate', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('wallfahrt', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('auwald', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('staatsverband', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('leichtsinn', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('christbaumschmuck', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('institut', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 19),
#  (('übernachtungszahl', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('teilerfolg', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('fischerei', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('verfassungsentwurf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('sprachengesetz', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('vorfall', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('hilfsprojekt', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('eigenaufsicht', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('bankhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('kinderhaus', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('landsmann', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 3),
#  (('präsidentengehalt', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('wahlzeit', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('dienstplan', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('besseres', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('bericht', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 52),
#  (('combox', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('abschiebepraxis', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('softwareprogramm', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('winterprogramm', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('klub', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('sippenhaft', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('labor', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 3),
#  (('anspruch', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 7),
#  (('montag', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 6),
#  (('ackerbau', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('industriemuseum', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('aufhebungsvertrag', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('stabilitätspakt', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 9),
#  (('wahltag', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 5),
#  (('weltmarktpreis', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('gerstensaft', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('referat', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('hundepflegesalon', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('ausstoß', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('politikmodell', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('verruf', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('sprachgewirr', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('rennen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 6),
#  (('neid', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('schelm', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('dauerlüften', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('trauergerüst', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('vergewaltigungsfall', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('atomschild', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('ausruhen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('wetterleuchten', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('aufschnüren', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('weltkrieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('hasch', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('linolschnitt', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('spagat', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('kriegsheld', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('spitzentreffen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('regierungslager', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('ayatollah', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('besitz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('privatleben', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('arbeitsbeschaffungsprogramm', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('gemeindebund', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('überlebensdauer', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('eleganz', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('poolen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('präsidiumsplatz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('holz', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('bemühen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('beweis', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 8),
#  (('kolloqium', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('mittelfranken', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('tatzeit', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 5),
#  (('nationalbank', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('komfortauskunft', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('forderungskatalog', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('märz', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 9),
#  (('scheitern', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 6),
#  (('höchstmaß', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('leuchtturm', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('brückenkopf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('bett', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 3),
#  (('wissenschaftsbetrieb', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('wettbewerbsvorteil', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('getränkekonzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('konflikt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 9),
#  (('spektakel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('stillen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('langzeittest', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('reisen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('rahmenabkommen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('einigungswerk', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('stehzeit', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('museumsshop', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('aids', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('vietnamsyndrom', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('prozeß', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 24),
#  (('finanzministerium', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('topf', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('philosophiererei', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('jähzorn', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('regierungsbank', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('anzahl', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 7),
#  (('sonderbeitrag', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('extrablatt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('zwecke', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 3),
#  (('lauf', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 5),
#  (('termin', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('ersatzplatz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('gejammere', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('europawahl', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('partei', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 72),
#  (('gebrauchtwagenschau', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('telefonnetz', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('schnitt', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('smoking', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('fußballklub', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('grenzverlauf', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('demokratisierungsprozeß', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('milliardenvermögen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('menschenrechte', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('gewehrfeuer', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('bekanntwerden', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 5),
#  (('einsicht', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 5),
#  (('mißmut', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('übernahmenangebot', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('ansehen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 7),
#  (('kleinstkind', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('gegenkandidatur', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 2),
#  (('gefängnispersonal', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('finanzgericht', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('durchschnitt', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('fluglärm', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('gewerkschaftsbund', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('wechselspiel', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('chatting', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('blatt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('bedrängnis', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 3),
#  (('mißbrauch', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('händlervolk', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('bip', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 5),
#  (('ankunft', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('expräsident', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('kommandostruktur', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 4),
#  (('glied', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('schmerzensgeld', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('modernisierungsbedarf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('stabschef', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 5),
#  (('gesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 9),
#  (('gemeinschaftsunternehmen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('beispiel', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 112),
#  (('fall', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 93),
#  (('veranstaltungsort', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('ressortchef', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('transparenz', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('umweltverband', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('symposium', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('flugblatt', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('gasgeschäft', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('geisterschlacht', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('admiral', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('koalitionsvertrag', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('zwang', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('generalvikariat', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('clan', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('mauer', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 12),
#  (('segment', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 3),
#  (('strom', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 7),
#  (('typ', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 7),
#  (('erdabstand', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('album', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('fluchtweg', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('gebäude', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 13),
#  (('vollkornbrot', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('jugendstraflager', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('straßenverkehr', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('inland', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('boykott', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 13),
#  (('mißverständnis', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 4),
#  (('budgetstreit', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('vorhang', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('reformbündnis', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('elsässisch', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('notruf', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('western', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('metapher', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('zukunft', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 22),
#  (('mitleid', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('festspielhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('vorhaben', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 5),
#  (('geburtsort', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('pump', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('domstadt', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 2),
#  (('schimpfen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('gastwirt', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('fußball', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('stand', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('essenz', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('todesurteil', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('warenaustausch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('porsche', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('arbeitsförderungsgesetz', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('lohn', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('behagen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('wunderwerk', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('börsenverein', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('werbegeschrei', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('demokratiespiel', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('gedenken', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 5),
#  (('job', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('widerspruchsrecht', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('konferenz', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 10),
#  (('parlamentsausschuss', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('mietansatz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('sicht', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 5),
#  (('allianz', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 7),
#  (('universitätscampus', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('haushalt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('schweigen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 5),
#  (('bescheid', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('schlußstand', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('plott', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('fracht', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 4),
#  (('rohbenzin', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('umland', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('bauch', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('rapsfeld', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('opernfan', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('aid', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('gleichgewicht', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 4),
#  (('dutzend', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 5),
#  (('zeitdruck', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('überblick', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('unschuld', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 4),
#  (('rekrutierungsbasis', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 2),
#  (('zinssteuergesetz', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('wegrand', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('nützliches', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('kirchenparlament', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('kühlhaus', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('kraut', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('regime', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 9),
#  (('herrn', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('städtetag', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 3),
#  (('gesamtwerk', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('protokollchef', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('computerdenken', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('süd', 'NOUN|Case=Acc|Number=Sing'), 1),
#  (('anstieg', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 6),
#  (('verbot', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 21),
#  (('nachweis', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 4),
#  (('reden', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('stall', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('einzug', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 4),
#  (('eingangsportal', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('erdbeben', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('mafiaunwesen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('offiziersstand', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('dekor', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('ausfall', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('vorsprung', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 6),
#  (('salzwasser', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('kanzlerfreund', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('rektor', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 4),
#  (('erklärungsansatz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('gymnasialdirektor', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('gesetzgebungsverfahren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('frohsinn', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('umweltpreis', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('kost', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('mahnmal', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('prügel', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('mitarbeit', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 3),
#  (('einreiseverbot', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('geldschrank', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('ringen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('abschiedsfest', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('kartellgesetz', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('sozialversicherungssystem', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('weg', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 50),
#  (('exportspielraum', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('autobahngebühr', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('flüchtiges', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('gerücht', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('generalstab', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('forschungsamt', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('rundgang', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('informationsmaterial', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('fach', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 6),
#  (('unabhängigkeitskrieg', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('privatsektor', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('vorinstanz', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('netz', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 8),
#  (('kaiserreich', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('notdekret', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('auftritt', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 8),
#  (('schatz', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('erziehungssystem', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('heimarbeit', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('stelldichein', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('beschleunigungsgebot', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('stoff', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('zuhören', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('wächteruniform', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('grundstück', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('wochenarbeit', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('schwanzend', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('architekturzeitschrift', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('umsatzzuwachs', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('malerhandwerk', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('lichtblick', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 4),
#  (('himmelblau', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('paragraphenwerk', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('barmann', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('habgier', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('leitbild', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('krach', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('ablauf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('neubau', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 5),
#  (('preisniveau', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('kommunismus', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 7),
#  (('moment', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 7),
#  (('altersdurchschnitt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('abzug', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('produktionsstandort', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('empirismus', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('licht', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 13),
#  (('fortschritt', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 13),
#  (('bundesrechnungshof', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('symbol', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 4),
#  (('kanzlerkandidatur', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('nahost', 'NOUN|Case=Nom|Number=Sing'), 1),
#  (('pogromnacht', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 2),
#  (('töten', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('justizpalast', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('überzeugungsarbeit', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 2),
#  (('unsichtbarem', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('aufstieg', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('konfliktpotential', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('wohnzimmerschrank', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('diebstahl', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('willkür', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('ökosteuerreform', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('aktienpaket', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('strohfeuer', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('staatsbesitz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('prozentpunkt', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('meuterei', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 3),
#  (('hinsicht', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 20),
#  (('seeufer', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('trend', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 23),
#  (('besuch', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 13),
#  (('charterflug', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('aktienbank', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('bundesarbeitsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('weißbuch', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('wogen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('sperrfrist', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 2),
#  (('plattencover', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('bundesgerichtshof', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 9),
#  (('inschrift', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('skepsis', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 5),
#  (('gedankengut', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('gipfeltreffen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 6),
#  (('verkehrsmittel', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('warenverkehr', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('hochschulkonzil', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('kollisionskurs', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('html', 'NOUN|Case=Nom|Number=Sing'), 2),
#  (('anpassungstermin', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('dasein', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('fahrt', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 4),
#  (('beruf', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('handelsaustausch', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('rechnergoliath', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('pacht', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('überfall', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 3),
#  (('flugzeug', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 9),
#  (('vertrauen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 3),
#  (('park', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('weltmarkt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('porträt', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 7),
#  (('außenhandelsbank', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('reinheitsgebot', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('einkaufszentrum', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('bundeskartellamt', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 6),
#  (('publikumskollaps', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('schlußroundtable', 'NOUN|Case=Dat|Number=Sing'), 1),
#  (('selbst', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('waschbecken', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('wanken', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('wahn', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('brunnen', 'NOUN|Case=Dat|Number=Sing'), 1),
#  (('miteinander', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('grunde', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 19),
#  (('reisegeld', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('wettbewerbsdruck', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('samstagsarbeit', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('samstagsarbeit', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('finanzgericht', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('energiekonsens', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('staatsmann', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 3),
#  (('mw', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('nächsten', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('krieg', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 18),
#  (('alpendollar', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('kurskorrektur', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('bezirk', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 6),
#  (('pistenvergnügen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('pflichtversicherungsgesetz', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('kabinett', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 15),
#  (('vokabeltest', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('anbruch', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('vermerk', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('zündstoff', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('aufwertungsdruck', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('betrug', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 5),
#  (('einlaß', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('schneesturm', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('zaun', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('semmel', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('selbstbild', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('landesausschuß', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('zinsniveau', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('krieg', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 32),
#  (('verrat', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('parteiarbeit', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('harz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('cäsarenwahn', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('bip', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('stemmen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('vorjahresstand', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('präsenz', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 8),
#  (('militärregime', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 4),
#  (('zarte', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('wandlungsprozeß', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('putsch', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('warnruf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('rohöl', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('verteilungspartei', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('fühlen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('standard', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('hochhausviertel', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('leitantrag', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 3),
#  (('theatergefühl', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('gebühr', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 2),
#  (('studienkreuzfahrt', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('ölmangel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('handelswert', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('reformkurs', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('transparent', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('umzug', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('standortfaktor', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('reform', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 36),
#  (('machwerk', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('aufsichtsrat', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('temperatur', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 2),
#  (('kriegswaffenkontrollgesetz', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('herumgerede', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('konsumismus', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('steuerfall', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('aufklärungsbedarf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('werbetour', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('verwaltungsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('ausschuß', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 10),
#  (('lebensarbeitszeit', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('fahrschein', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('volksstaat', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('musterbeispiel', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('kampflied', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('duo', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('kurzarbeitergeld', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('weltbank', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 3),
#  (('interesse', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 27),
#  (('beihilfefall', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('kuppel', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 2),
#  (('attentat', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 13),
#  (('sehen', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('gewahrsam', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('limit', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('heim', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('reformkurs', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('akademiegebäude', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('zigarettenkauf', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('lebensnerv', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('pflicht', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 3),
#  (('landesbank', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('melatonin', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 4),
#  (('verlauf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('gelände', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 13),
#  (('werbespot', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('mikrokosmos', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('mm', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('gerichtssaal', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('friedenslied', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('bauern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('mutter', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 6),
#  (('ehemann', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('plenum', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('eingeständnis', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('vertrauensvotum', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('showbusines', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('mehrheitsaktionär', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('witz', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('flaggschiff', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('ultraschall', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('flachs', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('ausland', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 6),
#  (('wirkstoff', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('steuerpaß', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('zweck', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 12),
#  (('dumping', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('verkauf', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 16),
#  (('quadrat', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('fachwelt', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('höhenluft', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('tanzabend', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('ende', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 164),
#  (('zuschnitt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('nettogewinn', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('spektakel', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 4),
#  (('feindbild', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('senator', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('asylpraxis', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('budgetplan', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('tageshoch', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('sonderfonds', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('aus', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('schwarzgeld', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('bieten', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('tiefschlaf', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('kuhmist', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('dienstleistungsverkehr', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('hehl', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 4),
#  (('rekordergebnis', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('ruhmeswahn', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('zusammenschluß', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 11),
#  (('motor', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 5),
#  (('haupt', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('völkerrecht', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('boykott', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 7),
#  (('vorzeigeklub', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('vorzug', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 6),
#  (('aufenthalt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 3),
#  (('innenhof', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('arbeitgeberverband', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 3),
#  (('stellenwert', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('festland', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('ausbau', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 7),
#  (('karlsruhe', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 7),
#  (('praxis', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 15),
#  (('aktionäre', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('hohn', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('vorgeformte', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('vizeplatz', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('markttransparenz', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('anfang', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 47),
#  (('donnerstag', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('gesamtkonzern', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('todesangst', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('investivlohn', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('pardon', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('gefängniss', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 4),
#  (('meuterei', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('finanzwelt', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('interpret', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('sekretariatssitz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('organisationsgrad', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('eselskopf', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('giersch', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('gemeinschaftsgeld', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('sarg', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('general', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 7),
#  (('saft', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('tabakkonsum', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('asylantrag', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('mönch', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 4),
#  (('vorsicht', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 3),
#  (('tagebuch', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('seitwärtstrend', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('glasbläserei', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('b', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('teleskop', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('katalog', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 5),
#  (('einhalt', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 3),
#  (('umkreis', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 3),
#  (('mißtrauensvotum', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('wettbewerb', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 23),
#  (('actionfilm', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('expertenansicht', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('forschungsschiff', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('gutshaus', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('rundumschlag', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('waldparkplatz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('haftpflichtverband', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('verdruß', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('pensionsfonds', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('kanton', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('rausschmiß', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('ausnutzen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('reaktor', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('nehmen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('kamerateam', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('zeitlang', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 3),
#  (('hochschulwesen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('abriß', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('bild', 'NOUN|Case=Nom|Number=Sing'), 2),
#  (('untersuchungsgefängnis', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('kaminfeuer', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('ziel', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 50),
#  (('nationalsinn', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('mehrzahl', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 2),
#  (('schirmherr', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('rekordergebnis', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('unterkunft', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 4),
#  (('konsum', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('erwekkungserlebnis', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('frauenkonferenz', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('beschäftigungspakt', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('arbeitsschutz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('blatt', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('jahresverlauf', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('genick', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('erlaubnis', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 5),
#  (('forderungskatalog', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('gen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 4),
#  (('zusatz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('rabattpraxis', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('schriftstellerei', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('zentralrat', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('preisverfall', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('kraftfahrthaftpflichtschutz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('akademikersteuer', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('visumspflicht', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('unguten', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('vkse', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('finanzgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('experimentator', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('festspielhaus', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('kongreß', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('preis', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 25),
#  (('eurogeld', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 7),
#  (('sprachengesetz', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('distanz', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 12),
#  (('staatsoberhaupt', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('verein', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 8),
#  (('platz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 10),
#  (('artenvielfalt', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 2),
#  (('sportsmann', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('reformprozeß', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('chaos', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 10),
#  (('theaterhaus', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('aufruf', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 5),
#  (('praxis', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 7),
#  (('jagd', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 2),
#  (('organismus', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('dokumentarmaterial', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('menschenverstand', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('staatsdefizit', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('generalsstabschef', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('besuch', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 42),
#  (('rhythmus', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 3),
#  (('pauschalprogramm', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('seetang', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('feldmarschall', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('engagement', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 11),
#  (('schleuderkurs', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('ostteil', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 5),
#  (('waffengewalt', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 4),
#  (('korruptionsskandal', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('transportgewerbe', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('streitfall', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('verschulden', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('religionsunterricht', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('rückzug', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 10),
#  (('relief', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('flügelschlagen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 2),
#  (('verhängnis', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('vergleichsantrag', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 2),
#  (('erdöl', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('jesuit', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('lösemittel', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('regelungswut', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('bankgewerbe', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('aufkommen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('zutritt', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 5),
#  (('supervisor', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('oberverwaltungsgericht', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 2),
#  (('sabbatjahr', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('prozent', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 9),
#  (('markt', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 42),
#  (('naturschutzbund', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('milliardenprojekt', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('schwerbehindertenausweis', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('wahlabend', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('holz', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('tag', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 60),
#  (('gepäckservice', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('bezirksnaturschutzwart', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('zahnersatz', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('brennelementewerk', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('aufsichtsrat', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('bruch', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('monatsarbeitszeit', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('bundeshaushalt', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('enarch', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('kennenlernen', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('fluch', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('staatssicherheitsgericht', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 2),
#  (('vorsitz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('wintereinbruch', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('initiativantrag', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('sitz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 12),
#  (('überzeugungsgrad', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('oberverwaltungsgericht', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 4),
#  (('lzb', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('start', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 12),
#  (('zwischenzeit', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('fachzeitschrift', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('anteil', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 30),
#  (('exkurs', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('finanzplan', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('steuerstrafverfahren', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('inkaufnehmen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('problemkind', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('unerkünften', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('haushalt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 10),
#  (('kündigungsschutz', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('anlauf', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('rollen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('aushängeschild', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('mittelpunkt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 27),
#  (('ersatzdienst', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('gewerbesteuer', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('erhalten', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('entscheiden', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('abhören', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('plan', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 11),
#  (('kulturbetrieb', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 2),
#  (('großform', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('weite', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('herkunft', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 3),
#  (('kompaniechef', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('stichwort', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 3),
#  (('landeskrankenhaus', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('laus', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 2),
#  (('abgang', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('schlepp', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('hafenschlamm', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('rücklauf', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('sorgerecht', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('konflikt', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 19),
#  (('ertrag', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 6),
#  (('eigelb', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('treibhaus', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('kulturbund', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('vorziehen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('yuan', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('grundgebühr', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('rettungsschuß', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('unternehnmerverband', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('geburtstag', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 8),
#  (('standardauskunft', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('kanzleramt', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 6),
#  (('tritonus', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('berufsbeamtentum', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('bundesvertretertag', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('terrain', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 8),
#  (('innenraum', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('golf', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('mensch', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('haß', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 4),
#  (('personaleinsatz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('konferenzzentrum', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('betriebsverfassungsgesetz', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('kerzenschein', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('merkmal', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('geschichtssinn', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('gebiet', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 5),
#  (('schachzug', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('währungsfonds', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('gesamtumsatz', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('neugier', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('holding', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('stellenzuwachs', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('staatssektor', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('verhandlungsergebnis', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('kilometerpreis', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('beamtenstatus', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('rohstoff', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('bestehen', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 2),
#  (('beschäftigtenzahl', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 13),
#  (('schritt', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('tat', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 20),
#  (('rebbergbahn', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 1),
#  (('nachsommernachmittag', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 1),
#  (('umweltschutz', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 14),
#  (('notwehr', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('brandherd', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('lizenz', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 3),
#  (('humor', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('inneren', 'NOUN|Case=Gen|Gender=Neut|Number=Sing'), 1),
#  (('mischkonzern', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 4),
#  (('flucht', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 20),
#  (('landwirtschaftsbank', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('importprodukt', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('erfolgsrezept', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('balkon', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('weltkrieg', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 15),
#  (('macht', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 43),
#  (('clan', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('rotationsprinzip', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('nachbarn', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 2),
#  (('vorsicht', 'NOUN|Case=Acc|Gender=Fem|Number=Sing'), 1),
#  (('sicherheitsprogramm', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('schiff', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 3),
#  (('idealverein', 'NOUN|Case=Gen|Gender=Masc|Number=Sing'), 1),
#  (('raubbau', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('studienjahr', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('chip', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('chemiekonzern', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 3),
#  (('hilfeappell', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('firmenchef', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 4),
#  (('zusammenarbeit', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 20),
#  (('theater', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 20),
#  (('existenz', 'NOUN|Case=Nom|Gender=Fem|Number=Sing'), 8),
#  (('dg', 'NOUN|Case=Nom|Number=Sing'), 1),
#  (('einzelpunkt', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('bargeld', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('verkehrsweg', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('schwangerschaftstest', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  (('brief', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 24),
#  (('partitur', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('fluchtweg', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 2),
#  (('skiurlaub', 'NOUN|Case=Nom|Gender=Masc|Number=Sing'), 3),
#  (('freizeitsport', 'NOUN|Case=Dat|Gender=Masc|Number=Sing'), 1),
#  (('miliz', 'NOUN|Case=Dat|Gender=Fem|Number=Sing'), 1),
#  (('ufer', 'NOUN|Case=Acc|Gender=Neut|Number=Sing'), 1),
#  (('glorifizieren', 'NOUN|Case=Dat|Gender=Neut|Number=Sing'), 1),
#  (('aussetzen', 'NOUN|Case=Nom|Gender=Neut|Number=Sing'), 1),
#  (('sitzplatzanspruch', 'NOUN|Case=Acc|Gender=Masc|Number=Sing'), 1),
#  ...}

# %%
lexicon += {(word.capitalize(), "NOUN|"+tag.split("Gender=")[1][0] if "Gender" in tag else "NOUN|S") for (word, tag), _ in sing_nouns}

# %%
de_sorted = list(filter(lambda c: not re.match(r'^NOUN', c[0][1]), de_sorted))

# %%
# enumerate proper nouns - only one inflection class with simple contextual differences
# plurals - keeps correct form of 'beatles' and 'bahamas', but 'schneiders' should be singular
plurals = list(filter(lambda c: re.match(r'^PROPN.*Case=(Nom|Acc|Dat).*Number=Plur', c[0][1]), de_sorted))
lexicon += {(word.capitalize(), "PRPN|P") for (word, tag), _ in plurals}

# %%
singular = list(filter(lambda c: re.match(r'^PROPN.*Case=(Nom|Acc|Dat).*Number=Sing', c[0][1]), de_sorted))
lexicon += {(word.capitalize(), "PRPN|"+tag.split("Gender=")[1][0] if "Gender" in tag else "PRPN|S") for (word, tag), _ in singular}

# %%
de_sorted = list(filter(lambda c: not re.match(r'^PROPN', c[0][1]), de_sorted))

# %%
# write lexicon to file
with open("lexicon.txt", "w") as f:
    for (word, tag) in lexicon:
        f.write(str(word)+'\t'+str(tag)+'\n')
